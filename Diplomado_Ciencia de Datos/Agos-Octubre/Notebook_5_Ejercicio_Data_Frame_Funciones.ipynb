# %% [markdown]
# <table>
#         <td>
#         <td><img src="https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/logo_ECI.png" width="400"/></td>
#         <td>&nbsp;</td>
#         <td>
#             <h1 style="font-size:200%;color:blue;text-align:center">    <FONT COLOR="blue"> DataFrames </p> Ejercicio </p> Funciones en Python  </FONT>         </h1></td>
#         <td>
#             <tp><p style="font-size:99%;text-align:center">Diplomado Ciencia de Datos </p></tp>
#             <tp><p style="font-size:115%;text-align:center">2026-2</p></tp>
#             <tp><p style="font-size:115%;text-align:center">Prof. Fabián Sánchez</p></tp>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # <FONT SIZE=5 COLOR="blue"> Contenidos del Notebook </FONT>
#
# En este notebook encontrará:
#
# - Repaso de elementos de exploración de Dataframes usando Pandas
#
# - Funciones en Python
#
# ```python
# def function(x):
#   ....
#   return ...
# ```

# %% [markdown]
# # <FONT SIZE=5 COLOR="purple"> 1. Ejercicio de Exploración y Limpieza de los Datos </FONT>
#
# **Contexto de los datos**
#
# Este conjunto de datos contiene información financiera y demográfica de individuos relacionada con el uso y posesión de tarjetas de crédito. El objetivo principal es analizar los factores asociados a la tenencia de una tarjeta de crédito y estudiar el comportamiento financiero de los clientes.
#
# Las variables incluyen características personales (edad, ingresos, número de dependientes), características laborales (trabajador independiente o no), situación patrimonial (propietario de vivienda) e información crediticia (historial de reportes negativos, número de tarjetas y cuentas activas).
#
# Este conjunto de datos es ampliamente utilizado en cursos de estadística, minería de datos y aprendizaje automático para ilustrar técnicas de análisis exploratorio, filtrado de datos, agrupamiento (`groupby`), visualización y modelos de clasificación.
#
# La variable de mayor interés suele ser `card`, que indica si una persona posee o no una tarjeta de crédito. A partir de las demás variables, es posible identificar patrones que ayuden a explicar o predecir dicha condición.
#
#
# | Variable | Traducción | Descripción |
# |-----------|------------|-------------|
# | `card` | Tarjeta | Indica si la persona posee una tarjeta de crédito (sí/no). |
# | `reports` | Reportes negativos | Número de reportes negativos o incidentes en el historial crediticio. |
# | `age` | Edad | Edad de la persona (años). |
# | `income` | Ingreso | Ingreso anual del individuo o hogar. |
# | `share` | Proporción de gasto | Proporción del ingreso destinada a gastos con tarjeta. |
# | `expenditure` | Gasto | Gasto mensual realizado con tarjeta de crédito. |
# | `owner` | Propietario de vivienda | Indica si posee vivienda propia (sí/no). |
# | `selfemp` | Trabajador independiente | Indica si es trabajador independiente o autónomo (sí/no). |
# | `dependents` | Dependientes | Número de personas dependientes económicamente. |
# | `months` | Meses de historial | Meses de historial crediticio o de permanencia en el sistema financiero. |
# | `majorcards` | Tarjetas principales | Número de tarjetas de crédito principales que posee. |
# | `active` | Cuentas activas | Número de cuentas de crédito activas. |
#
# link de los datos
#
#
#
# ```python
# https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/credict_para_limpiar.csv
# ```

# %% [markdown]
# Iniciaremos importando la librería *pandas*

# %%
# importamos las librerías
import pandas as pd
import numpy as np

# %%
# cargamos los datos crédito
credito = pd.read_csv("https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/credict_para_limpiar.csv")
credito.head()  # na_values("")
# Out:
#   Trajeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 0     yes                   0  37.66667   4.5200             0.033270
# 1     yes                   0     33.25   2.4200             0.005217
# 2     yes                   0  33.66667   4.5000             0.004156
# 3     yes                   0      30.5   2.5400             0.065214
# 4     yes                   0  32.16667   9.7867             0.067051
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 0  124.983300                     yes                     no             3
# 1    9.854167                      no                     no             3
# 2   15.000000                     yes                     no             4
# 3  137.869200                      no                     no             0
# 4  546.503300                     yes                     no             2
#
#   Meses de Historial  Tarjetas Principales  Cuentas Activas
# ...

# %% [markdown]
# A continuación haremos una exploración rápida de los datos para identificar posibles inconsistencia y poderlas solucionar.

# %%
# los primeros datos
credito.head()
# Out:
#   Trajeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 0     yes                   0  37.66667   4.5200             0.033270
# 1     yes                   0     33.25   2.4200             0.005217
# 2     yes                   0  33.66667   4.5000             0.004156
# 3     yes                   0      30.5   2.5400             0.065214
# 4     yes                   0  32.16667   9.7867             0.067051
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 0  124.983300                     yes                     no             3
# 1    9.854167                      no                     no             3
# 2   15.000000                     yes                     no             4
# 3  137.869200                      no                     no             0
# 4  546.503300                     yes                     no             2
#
#   Meses de Historial  Tarjetas Principales  Cuentas Activas
# ...

# %% [markdown]
# observamos algunas variables numéricas y otras categóricas

# %%
# últimos registros a modo de exploración
credito.tail()
# Out:
#      Trajeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 1314     yes                   0  33.58333    4.566             0.002146
# 1315      no                   5  23.91667    3.192             0.000376
# 1316     yes                   0  40.58333    4.600             0.026513
# 1317     yes                   0  32.83333    3.700             0.008999
# 1318     yes                   0     48.25    3.700             0.111619
#
#            Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 1314    7.333333                     yes                     no             0
# 1315    0.000000                      no                     no             3
# 1316  101.298300                     yes                     no             2
# 1317   26.996670                      no                    yes             0
# 1318  344.157500                     yes                     no             2
#
# ...

# %%
# tamaño de los datos
credito.shape
# Out:
# (1319, 12)

# %%
# nombres de las columnas
credito.columns
# Out:
# Index(['Trajeta', 'Reportes Negativos', 'Edad', 'Ingreso',
#        'Proporcion de Gasto', 'Gasto', 'Propietario de Vivienda',
#        'Trabajor Independiente', 'Dependientes', 'Meses de Historial',
#        'Tarjetas Principales', 'Cuentas Activas'],
#       dtype='object')

# %% [markdown]
# Aca identificamos una primera cosa que podemos cambiar:
#
# - Nombre de la primera variable

# %%
# cambiar el nombre de la primera variable
credito.rename(columns={"Trajeta": "Tarjeta"}, inplace=True)
credito.head()
# Out:
#   Tarjeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 0     yes                   0  37.66667   4.5200             0.033270
# 1     yes                   0     33.25   2.4200             0.005217
# 2     yes                   0  33.66667   4.5000             0.004156
# 3     yes                   0      30.5   2.5400             0.065214
# 4     yes                   0  32.16667   9.7867             0.067051
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 0  124.983300                     yes                     no             3
# 1    9.854167                      no                     no             3
# 2   15.000000                     yes                     no             4
# 3  137.869200                      no                     no             0
# 4  546.503300                     yes                     no             2
#
#   Meses de Historial  Tarjetas Principales  Cuentas Activas
# ...

# %% [markdown]
# Ahora, veamos la información de los datos. Resumen

# %%
# información de los datos
credito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Tarjeta                  1319 non-null   object
#  1   Reportes Negativos       1319 non-null   int64
#  2   Edad                     1317 non-null   object
#  3   Ingreso                  1318 non-null   float64
#  4   Proporcion de Gasto      1318 non-null   float64
#  5   Gasto                    1319 non-null   float64
#  6   Propietario de Vivienda  1318 non-null   object
#  7   Trabajor Independiente   1317 non-null   object
#  8   Dependientes             1319 non-null   int64
#  9   Meses de Historial       1314 non-null   object
#  10  Tarjetas Principales     1319 non-null   int64
#  11  Cuentas Activas          1318 non-null   float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 123.8+ KB

# %% [markdown]
# En esta parte identificamos algunos elementos
#
# - Algunas variables tienen datos faltantes
#
# $$datos.isna().sum()$$
#
# - La variable edad esta tipo object. Debe ser numérica
#
# - Los Meses de Historial también debería ser un número, está como tipo object.

# %%
credito.isna()
# Out:
#       Tarjeta  Reportes Negativos   Edad  Ingreso  Proporcion de Gasto  Gasto  \
# 0       False               False  False    False                False  False
# 1       False               False  False    False                False  False
# 2       False               False  False    False                False  False
# 3       False               False  False    False                False  False
# 4       False               False  False    False                False  False
# ...       ...                 ...    ...      ...                  ...    ...
# 1314    False               False  False    False                False  False
# 1315    False               False  False    False                False  False
# 1316    False               False  False    False                False  False
# 1317    False               False  False    False                False  False
# 1318    False               False  False    False                False  False
#
# ...

# %%
# para ver la cantidad de datos por columna
credito.isna().sum()
# Out:
# Tarjeta                    0
# Reportes Negativos         0
# Edad                       2
# Ingreso                    1
# Proporcion de Gasto        1
# Gasto                      0
# Propietario de Vivienda    1
# Trabajor Independiente     2
# Dependientes               0
# Meses de Historial         5
# Tarjetas Principales       0
# Cuentas Activas            1
# dtype: int64

# %% [markdown]
# Antes de continuar con las estadísticas descriptivas vamos a solucionar los problemas anteriores.
#
# 1. Para los valores con datos faltantes:
#
# Como son pocos datos, podríamos eliminarlos todos del dataframe con la instrucción
#
# $$datos.dropna()$$
#
# Sin embargo haremos dos procesos a modo de practica.
#
# 1. Cambiaremos los datos faltantes de la variable edad por el promedio.
#
# $$datos.variable.fillna(valor, ...)$$
#
# 2. El restante de valores los eliminaremos
#
# Sin embargo, hay un problema: la variable Edad es tipo *object* y así no se puede reemplazar los NA y tampoco calcular el promedio.
# Debemos revisarla primero.

# %%
# cambiar los datos faltantes de la variable edad de credito por el promedio de edad
credito.Edad.fillna(credito.Edad.mean(), inplace=True)
credito.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_645/1686938829.py in <cell line: 0>()
#       1 # cambiar los datos faltantes de la variable edad de credito por el promedio de edad
# ----> 2 credito.Edad.fillna(credito.Edad.mean(), inplace=True)
#       3 credito.info()
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
# ...

# %% [markdown]
# **Explorar la variable Edad**

# %%
# veamos valores únicos 0:10 revisar los 10 primeros
credito.Edad.unique()[0:10]
# Out:
# array(['37.66667', '33.25', '33.66667', '30.5', '32.16667', '23.25',
#        '27.91667', '29.16667', '37.0', '28.41667'], dtype=object)

# %% [markdown]
# Como están entre comillas, es coherente con el tipo object, es decir, esta siendo tomada como cadena de texto.
#
# Veamos donde está el problema con estos datos.

# %% [markdown]
# **Coerción**
#
# La coerción es el proceso mediante el cual un lenguaje o una función convierte automáticamente un dato de un tipo a otro para poder realizar una operación.
#
# $$pd.to\_numeric$$

# %%
# ejemplo de coerción
pd.to_numeric(credito.Edad, errors='coerce')
# Out:
# 0       37.66667
# 1       33.25000
# 2       33.66667
# 3       30.50000
# 4       32.16667
#           ...
# 1314    33.58333
# 1315    23.91667
# 1316    40.58333
# 1317    32.83333
# 1318    48.25000
# Name: Edad, Length: 1319, dtype: float64

# %%
# identificamos donde hay errores
pd.to_numeric(credito.Edad, errors='coerce').isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1314    False
# 1315    False
# 1316    False
# 1317    False
# 1318    False
# Name: Edad, Length: 1319, dtype: bool

# %%
# identificamos donde hay errores
pd.to_numeric(credito.Edad, errors='coerce').isna().sum()
# Out:
# np.int64(4)

# %% [markdown]
# Hay 4 valores con problemas
#
# Podemos usar la instrucción
#
# $$np.where()$$
#
# para revisar en cuáles posiciones están estos problemas

# %%
# identificamos las posiciones
np.where(pd.to_numeric(credito.Edad, errors='coerce').isna())
# Out:
# (array([ 11,  15, 116, 569]),)

# %%
# utilizamos iloc
credito.iloc[[ 11,  15, 116, 569]]
# Out:
#     Tarjeta  Reportes Negativos Edad  Ingreso  Proporcion de Gasto     Gasto  \
# 11       no                   0          1.98             0.000606    0.0000
# 15      yes                   0          3.20             0.125819  335.4350
# 116     yes                   1  NaN     2.00             0.060808  101.2625
# 569     yes                   0  NaN     2.10             0.321348  562.3592
#
#     Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 11                      yes                     no             2
# 15                      yes                     no             1
# 116                     yes                     no             3
# 569                      no                     no             0
#
#     Meses de Historial  Tarjetas Principales  Cuentas Activas
# 11                  36                     1              0.0
# 15                 168                     1             22.0
# 116                 42                     1              3.0
# ...

# %% [markdown]
# Observamos que hay dos valores vacíos y dos valores faltantes.

# %%
# ahora sí reescribo la coerción en la variable
credito["Edad"] = pd.to_numeric(credito["Edad"], errors="coerce")

# %%
credito.Edad.unique()[0:10]
# Out:
# array([37.66667, 33.25   , 33.66667, 30.5    , 32.16667, 23.25   ,
#        27.91667, 29.16667, 37.     , 28.41667])

# %%
np.where(pd.to_numeric(credito.Edad, errors='coerce').isna())
# Out:
# (array([ 11,  15, 116, 569]),)

# %% [markdown]
# La diferencia es que la variable es tipo numérica

# %%
# = es de asignar
credito.Edad[[11,  15, 116, 569]] = credito.Edad.mean()
# Out:
# /tmp/ipykernel_645/2750239813.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   credito.Edad[[11,  15, 116, 569]] = credito.Edad.mean()
# /tmp/ipykernel_645/2750239813.py:2: SettingWithCopyWarning:
# ...

# %%
credito.iloc[[11,  15, 116, 569]]
# Out:
#     Tarjeta  Reportes Negativos       Edad  Ingreso  Proporcion de Gasto  \
# 11       no                   0  33.615526     1.98             0.000606
# 15      yes                   0  33.615526     3.20             0.125819
# 116     yes                   1  33.615526     2.00             0.060808
# 569     yes                   0  33.615526     2.10             0.321348
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 11     0.0000                     yes                     no             2
# 15   335.4350                     yes                     no             1
# 116  101.2625                     yes                     no             3
# 569  562.3592                      no                     no             0
#
#     Meses de Historial  Tarjetas Principales  Cuentas Activas
# 11                  36                     1              0.0
# 15                 168                     1             22.0
# ...

# %%
credito.Edad.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Ya no hay datos faltantes

# %% [markdown]
# **veamos la otra variable** `Meses de Historial`

# %%
credito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Tarjeta                  1319 non-null   object
#  1   Reportes Negativos       1319 non-null   int64
#  2   Edad                     1319 non-null   float64
#  3   Ingreso                  1318 non-null   float64
#  4   Proporcion de Gasto      1318 non-null   float64
#  5   Gasto                    1319 non-null   float64
#  6   Propietario de Vivienda  1318 non-null   object
#  7   Trabajor Independiente   1317 non-null   object
#  8   Dependientes             1319 non-null   int64
#  9   Meses de Historial       1314 non-null   object
#  10  Tarjetas Principales     1319 non-null   int64
#  11  Cuentas Activas          1318 non-null   float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 123.8+ KB

# %%
credito["Meses de Historial"].unique()[0:20]
# Out:
# array(['54', '34', '5o', '25', '64', '7', '77', '97', '65', '24', '36',
#        '42', '26', '12o', '168', '96', '60', '28', '115', '12'],
#       dtype=object)

# %%
# revisar cadenas de texto en months
credito["Meses de Historial"].unique()[0:10]
# Out:
# array(['54', '34', '5o', '25', '64', '7', '77', '97', '65', '24'],
#       dtype=object)

# %% [markdown]
# De igual forma es cadena de texto

# %%
# veamos cuantos problemas hay.
pd.to_numeric(credito["Meses de Historial"], errors='coerce').isna().sum()
# Out:
# np.int64(8)

# %%
np.where(  pd.to_numeric(credito["Meses de Historial"], errors='coerce').isna()  )
# Out:
# (array([  2,  14,  32, 252, 320, 399, 465, 496]),)

# %%
# veamos donde están los problemas
np.where(pd.to_numeric(credito["Meses de Historial"], errors='coerce').isna())[0]
# Out:
# array([  2,  14,  32, 252, 320, 399, 465, 496])

# %%
credito.iloc[[2,  14,  32, 252, 320, 399, 465, 496]]
# Out:
#     Tarjeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 2       yes                   0  33.66667    4.500             0.004156
# 14      yes                   0  35.33333    1.908             0.026907
# 32       no                   1  24.91667    3.150             0.000381
# 252     yes                   0  25.08333    2.650             0.009651
# 320      no                   2  28.16667    2.600             0.000462
# 399     yes                   0  22.58333    2.250             0.011111
# 465      no                   0  23.83333    2.200             0.000545
# 496     yes                   0  42.25000    3.235             0.024766
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 2    15.00000                     yes                     no             4
# 14   42.61500                     yes                     no             2
# 32    0.00000                     yes                     no             1
# ...

# %%
#credito.iloc[list(np.where(pd.to_numeric(credito.months, errors='coerce').isna())[0])]

# %% [markdown]
# Haremos dos cosas
#
# - Eliminados los NA
#
# - Cambiamos la "o" por "0".

# %%
# para eliminar NA's
credito.dropna(inplace=True)

# %%
credito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 1318
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Tarjeta                  1309 non-null   object
#  1   Reportes Negativos       1309 non-null   int64
#  2   Edad                     1309 non-null   float64
#  3   Ingreso                  1309 non-null   float64
#  4   Proporcion de Gasto      1309 non-null   float64
#  5   Gasto                    1309 non-null   float64
#  6   Propietario de Vivienda  1309 non-null   object
#  7   Trabajor Independiente   1309 non-null   object
#  8   Dependientes             1309 non-null   int64
#  9   Meses de Historial       1309 non-null   object
#  10  Tarjetas Principales     1309 non-null   int64
#  11  Cuentas Activas          1309 non-null   float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 132.9+ KB

# %%
# volvemos a revisar
np.where(pd.to_numeric(credito["Meses de Historial"], errors='coerce').isna())
# Out:
# (array([ 2, 13, 29]),)

# %%
# volvemos a revisar
np.where(pd.to_numeric(credito["Meses de Historial"], errors='coerce').isna())[0]
# Out:
# array([ 2, 13, 29])

# %%
credito.iloc[[ 2, 13, 29]]
# Out:
#    Tarjeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 2      yes                   0  33.66667    4.500             0.004156
# 14     yes                   0  35.33333    1.908             0.026907
# 32      no                   1  24.91667    3.150             0.000381
#
#      Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 2   15.000                     yes                     no             4
# 14  42.615                     yes                     no             2
# 32   0.000                     yes                     no             1
#
#    Meses de Historial  Tarjetas Principales  Cuentas Activas
# 2                  5o                     1              5.0
# 14                12o                     0              5.0
# 32                 4o                     1              5.0

# %%
# reemplazar la o por 0 en la variable Meses de Historial
credito["Meses de Historial"] = credito["Meses de Historial"].str.replace("o", "0")

# %%
credito.iloc[[2, 13, 29]]
# Out:
#    Tarjeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 2      yes                   0  33.66667    4.500             0.004156
# 14     yes                   0  35.33333    1.908             0.026907
# 32      no                   1  24.91667    3.150             0.000381
#
#      Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 2   15.000                     yes                     no             4
# 14  42.615                     yes                     no             2
# 32   0.000                     yes                     no             1
#
#    Meses de Historial  Tarjetas Principales  Cuentas Activas
# 2                  50                     1              5.0
# 14                120                     0              5.0
# 32                 40                     1              5.0

# %%
credito["Meses de Historial"].unique()[0:10]
# Out:
# array(['54', '34', '50', '25', '64', '7', '77', '97', '65', '24'],
#       dtype=object)

# %%
# convertir a numérico
credito["Meses de Historial"] = pd.to_numeric(credito["Meses de Historial"], errors="coerce")

# %%
credito.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 1318
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Tarjeta                  1309 non-null   object
#  1   Reportes Negativos       1309 non-null   int64
#  2   Edad                     1309 non-null   float64
#  3   Ingreso                  1309 non-null   float64
#  4   Proporcion de Gasto      1309 non-null   float64
#  5   Gasto                    1309 non-null   float64
#  6   Propietario de Vivienda  1309 non-null   object
#  7   Trabajor Independiente   1309 non-null   object
#  8   Dependientes             1309 non-null   int64
#  9   Meses de Historial       1309 non-null   int64
#  10  Tarjetas Principales     1309 non-null   int64
#  11  Cuentas Activas          1309 non-null   float64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 132.9+ KB

# %% [markdown]
# **Para pensar un poco**
#
# ¿Para no estar definiendo en cada momento los mismos elementos, puedo definir algún objeto para utilizarlo en ciertos procesos?
#
# ```python
# # función para detectar
# def problema_texto(datos, x):
#   u = pd.to_numeric(datos[x], errors='coerce').isna()
#   posiciones = np.where(u)[0]
#   print(posiciones)
#   return datos.iloc[posiciones]
# ```

# %%
# cargamos los datos crédito
credito2 = pd.read_csv("https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/credict_para_limpiar.csv")
credito2.head()  # na_values("")
# Out:
#   Trajeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 0     yes                   0  37.66667   4.5200             0.033270
# 1     yes                   0     33.25   2.4200             0.005217
# 2     yes                   0  33.66667   4.5000             0.004156
# 3     yes                   0      30.5   2.5400             0.065214
# 4     yes                   0  32.16667   9.7867             0.067051
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 0  124.983300                     yes                     no             3
# 1    9.854167                      no                     no             3
# 2   15.000000                     yes                     no             4
# 3  137.869200                      no                     no             0
# 4  546.503300                     yes                     no             2
#
#   Meses de Historial  Tarjetas Principales  Cuentas Activas
# ...

# %%
def problema_texto(datos, x):
  u = pd.to_numeric(datos[x], errors='coerce').isna()
  posiciones = np.where(u)[0]
  print(posiciones)
  return datos.iloc[posiciones]

# %%
problema_texto(credito2,"Meses de Historial")
# Out:
# [  2  14  32 252 320 399 465 496]
#     Trajeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 2       yes                   0  33.66667    4.500             0.004156
# 14      yes                   0  35.33333    1.908             0.026907
# 32       no                   1  24.91667    3.150             0.000381
# 252     yes                   0  25.08333    2.650             0.009651
# 320      no                   2  28.16667    2.600             0.000462
# 399     yes                   0  22.58333    2.250             0.011111
# 465      no                   0  23.83333    2.200             0.000545
# 496     yes                   0     42.25    3.235             0.024766
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 2    15.00000                     yes                     no             4
# 14   42.61500                     yes                     no             2
# ...

# %% [markdown]
# Continuemos con la exploración:
#
# Ahora veamos las categorias de las variables tipo object

# %%
credito.describe()
# Out:
#        Reportes Negativos         Edad      Ingreso  Proporcion de Gasto  \
# count         1309.000000  1309.000000  1309.000000          1309.000000
# mean             0.453018    33.636016     3.365272             0.076818
# std              1.337063    18.818866     1.689178             0.186818
# min              0.000000  -120.000000     0.210000             0.000109
# 25%              0.000000    25.416670     2.236000             0.002424
# 50%              0.000000    31.250000     2.900000             0.039573
# 75%              0.000000    39.416670     4.000000             0.094789
# max             14.000000   560.000000    13.500000             3.890000
#
#              Gasto  Dependientes  Meses de Historial  Tarjetas Principales  \
# count  1309.000000   1309.000000         1309.000000           1309.000000
# mean    185.843156      0.992361           55.470588              0.816654
# std     272.755147      1.245151           66.463184              0.387098
# ...

# %%
credito.describe(include = "object")
# Out:
#        Tarjeta Propietario de Vivienda Trabajor Independiente
# count     1309                    1309                   1309
# unique       4                       4                      2
# top        yes                      no                     no
# freq      1012                     734                   1219

# %%
credito["Tarjeta"].value_counts()
# Out:
# Tarjeta
# yes    1012
# no      289
# Yes       5
# No        3
# Name: count, dtype: int64

# %% [markdown]
# observamos que hay cuatro categorias y deben ser dos

# %%
# cambiar Yes y No por yes o no
#credito["Tarjeta"] = credito["Tarjeta"].str.lower()
credito["Tarjeta"] = credito["Tarjeta"].replace({"Yes": "yes", "No": "no"})

# %%
credito["Tarjeta"].value_counts()
# Out:
# Tarjeta
# yes    1017
# no      292
# Name: count, dtype: int64

# %% [markdown]
#   **Para pensar un poco**
#
# ¿Cómo podemos hacer el proceso para todas las columnas?
#
# ```python
# for name in credito.columns:
#   if credito[name].dtype == "object":
#     u=credito[name].unique()
#     print(name , u)
# ```

# %% [markdown]
# Más adelante responderemos esas preguntas, por ahora, sigamos con la exploración.

# %%
#estadísticas descriptivas: cuantitativas
credito.describe()
# Out:
#        Reportes Negativos         Edad      Ingreso  Proporcion de Gasto  \
# count         1309.000000  1309.000000  1309.000000          1309.000000
# mean             0.453018    33.636016     3.365272             0.076818
# std              1.337063    18.818866     1.689178             0.186818
# min              0.000000  -120.000000     0.210000             0.000109
# 25%              0.000000    25.416670     2.236000             0.002424
# 50%              0.000000    31.250000     2.900000             0.039573
# 75%              0.000000    39.416670     4.000000             0.094789
# max             14.000000   560.000000    13.500000             3.890000
#
#              Gasto  Dependientes  Meses de Historial  Tarjetas Principales  \
# count  1309.000000   1309.000000         1309.000000           1309.000000
# mean    185.843156      0.992361           55.470588              0.816654
# std     272.755147      1.245151           66.463184              0.387098
# ...

# %% [markdown]
# **¿Qué se puede observar?**

# %%
credito_filtrado = credito[credito.Edad.between(18,80)] # dataframe filtrado

# %%
credito = credito[credito.Edad.between(18,80)]

# %%
credito.describe()
# Out:
#        Reportes Negativos         Edad      Ingreso  Proporcion de Gasto  \
# count         1297.000000  1297.000000  1297.000000          1297.000000
# mean             0.454896    33.324630     3.362898             0.076900
# std              1.342449     9.720094     1.684846             0.187596
# min              0.000000    18.166670     0.210000             0.000109
# 25%              0.000000    25.416670     2.234800             0.002404
# 50%              0.000000    31.333330     2.900000             0.039305
# 75%              0.000000    39.333330     4.000000             0.094348
# max             14.000000    74.166660    13.500000             3.890000
#
#              Gasto  Dependientes  Meses de Historial  Tarjetas Principales  \
# count  1297.000000   1297.000000         1297.000000           1297.000000
# mean    185.561819      0.988435           55.511180              0.817271
# std     273.103419      1.240030           66.541237              0.386594
# ...

# %% [markdown]
# Lo que sigue es revisar las estadísticas descriptivas variable por variable y revisar si los valores son coherentes.
#
# Por ejemplo, la edad parece estar bien

# %%
credito.Edad.describe()
# Out:
# count    1297.000000
# mean       33.324630
# std         9.720094
# min        18.166670
# 25%        25.416670
# 50%        31.333330
# 75%        39.333330
# max        74.166660
# Name: Edad, dtype: float64

# %% [markdown]
# **Ejercicio 1**
#
# - Analice las estadísticas de la variable **Edad**.
#
# - Haga la tabla de frecuencia de la variable **Tarjeta** y de **Propietario de Vivienda**
#
# - Ahora, haga la tabla cruzada de las variables anteriores.
#
# - ¿Cuál es el promedio de **edad** por **propietario de vivienda**?
#
# - Calcule las estadísticas descriptivas del **Gasto** dependiendo del número de dependientes.
#
# **Ejercicio 2**
#
# - ¿Cuántas personas tienen 3 dependientes?
#
# - ¿Cuántas personas son propietarios de vivienda y tienen más de 30 meses de historial?
#
# - ¿Cuántas personas gastan menos de 200 us, no tienen vivienda propia y están entre 30 y 50 años?
#
# - ¿Cuántas personas tienen más (o igual) de 6 cuentas activas y fue negada la tarjeta de crédito?

# %% [markdown]
# # <FONT SIZE=5 COLOR="purple"> 2. Funciones en Python </FONT>
#
# - Las funciones son bloques de código reutilizables que permiten organizar y estructurar programas de manera eficiente.
#
# - Su principal objetivo es encapsular tareas específicas, facilitando la lectura, el mantenimiento y la reutilización del código.
#
# - En Python, las funciones se definen mediante la palabra clave *def*
# y pueden recibir parámetros de entrada, realizar operaciones y devolver resultados.
#
# ```python
# def function(x,y,x..):
#   .....
#   return ...
# ```
# - El uso de funciones contribuye a reducir la duplicación de código, mejorar la modularidad de los programas y simplificar la resolución de problemas complejos mediante su división en tareas más pequeñas.-
#
# - Favorecen la claridad del código y permiten desarrollar aplicaciones más robustas y fáciles de depurar.
#
# En esta sección se presentan los conceptos básicos relacionados con la definición, uso y aplicación de funciones en Python, así como algunos ejemplos prácticos.

# %%
def name():

# %%
# ejemplo básico de función sin parámetros
def saludo():
  print("Hola cómo están. Esto es un saludo")

# %% [markdown]
# cada vez que escribamos *saludo()*

# %%
saludo()
# Out:
# Hola cómo están. Esto es un saludo

# %%
# ejemplo de función que suma 4
def funcion(x):
  return(x+4)

# %%
# ejemplo básico de función con parámetros
def saludo2(nombre):
  print("Hola" , nombre, "Cómo estás?")

# %%
def saludito(nombre, apellido):
  print("Hola", nombre, apellido, "Cómo estas?")

# %%
saludito("Hugo", "Sanchez")
# Out:
# Hola Hugo Sanchez Cómo estas?

# %%
saludo2("Carlos")
# Out:
# Hola Carlos Cómo estás?

# %% [markdown]
# **Formas diferentes del print()**
#
# Para imprimir variables dentro del *print* hay varias alternativas
#
# - **f-strings**
#
# - **.format()**

# %% [markdown]
# **método f"{variable}"**

# %%
# primera forma
def saludo3(nombre):
  print("Hola", nombre, "espero que estés bien")

# %%
saludo3("Carolina")
# Out:
# Hola Carolina espero que estés bien

# %%
# método f"{variable}"
def saludo3(nombre):
  print(f"Hola, {nombre} espero que estes bien")

# %%
saludo3("Ana María")
# Out:
# Hola, Ana María espero que estes bien

# %% [markdown]
# **método "{}".format(variable)**

# %%
def saludo4(nombre):
  print("Hola {}, me alegra mucho verte".format(nombre))

# %%
saludo4("Carlos")
# Out:
# Hola Carlos, me alegra mucho verte

# %% [markdown]
# Las funciones pueden tener varios parámetros

# %%
# ejemplo de la suma
def suma(x,y):
  print(x+y)

# %%
x = suma(10,89)
# Out:
# 99

# %%
print(x)
# Out:
# None

# %%
suma(90,56)+10
# Out:
# 146
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_645/3414635881.py in <cell line: 0>()
# ----> 1 suma(90,56)+10
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
def suma2(x,y):
  return x+y

# %%
suma2(90,56)+10
# Out:
# 156

# %%
# veamos lo siguiente
x = suma(10,89)
# Out:
# 99

# %%
# veamos el valor de x
print(x)
# Out:
# None

# %%
y = suma2(10,89)
print(y)
# Out:
# 99

# %%
def suma2(x,y):
  return x+y

# %%
suma2(10,89)
# Out:
# 99

# %%
#hacemos lo mismo
x=suma2(10,89)
print(x)
# Out:
# 99

# %% [markdown]
# Podemos pensar como una calculadora.
#
# - **print**:
#
#   - la calculadora muestra el resultado en la pantalla.
#   - cuando se quiere mostrar únicamente la información
#
# - **return**:
#
#   - la calculadora te entrega el resultado para que puedas usarlo en otro cálculo.
#   - cuando queremos un resultados para seguir trabajando con él.

# %% [markdown]
# Veamos otros ejemplos de funciones

# %%
def funcion1(x,y):
  z = x**2+y**2+x*y**3+60
  return(z)

# %%
funcion1(10, 34)+1000
# Out:
# 395356

# %%
funcion1(-13,67)
# Out:
# -3905201

# %% [markdown]
# **Ejercicio**
#
# Generar funciones para:
#
# - Calcular el área de un rectángulo
# - Conversión de celsius a fahrenheit
# - Generar un correo intitucional: nombre.apellido@universidad.edu.co
# - Calculo el índice de masa corporal
# - Calcular interés simple

# %%
def area_rectangulo(base,altura):
  return base*altura

# %%
area_rectangulo(45,89)
# Out:
# 4005

# %%
# funcion indique número de fila y de número de columnas
def shape_datos(datos):
  print("El número de filas es" , datos.shape[0])
  print("El número de columnas es", datos.shape[1])

# %%
shape_datos(credito)
# Out:
# El número de filas es 1297
# El número de columnas es 12

# %%
def exploracion_rapida(datos):
  primeros = datos.head()
  ultimos = datos.tail()
  return primeros, ultimos

# %%
exploracion_rapida(credito)
# Out:
#   Tarjeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 0     yes                   0  37.66667   4.5200             0.033270
# 1     yes                   0  33.25000   2.4200             0.005217
# 2     yes                   0  33.66667   4.5000             0.004156
# 3     yes                   0  30.50000   2.5400             0.065214
# 4     yes                   0  32.16667   9.7867             0.067051
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 0  124.983300                     yes                     no             3
# 1    9.854167                      no                     no             3
# 2   15.000000                     yes                     no             4
# 3  137.869200                      no                     no             0
# 4  546.503300                     yes                     no             2
#
#    Meses de Historial  Tarjetas Principales  Cuentas Activas
# ...

# %%
#print
#return
#display..

# %%
def exploracion_prueba(datos):
    print("Primeros 5 registros \n")
    display(datos.head())

# %%
exploracion_prueba(credito)
# Out:
# Primeros 5 registros
#   Tarjeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 0     yes                   0  37.66667   4.5200             0.033270
# 1     yes                   0  33.25000   2.4200             0.005217
# 2     yes                   0  33.66667   4.5000             0.004156
# 3     yes                   0  30.50000   2.5400             0.065214
# 4     yes                   0  32.16667   9.7867             0.067051
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 0  124.983300                     yes                     no             3
# 1    9.854167                      no                     no             3
# 2   15.000000                     yes                     no             4
# 3  137.869200                      no                     no             0
# 4  546.503300                     yes                     no             2
#
#    Meses de Historial  Tarjetas Principales  Cuentas Activas
# ...

# %%
def exploracion(datos):
    print("Primeros 5 registros \n")
    display(datos.head())

    print("\n Últimos 5 registros \n")
    display(datos.tail())

    print("\n Tamaño de los datos \n")
    print(datos.shape)
    print(f"Filas: {datos.shape[0]}")
    print(f"Columnas: {datos.shape[1]}")

    print("\n Nombres de las columnas \n")
    print(datos.columns)

    print("\n Información de los datos \n")
    print(datos.info())

    print("\n Estadísticas descriptivas \n")
    display(datos.describe())

    print("\n Valores faltantes \n")
    display(datos.isna().sum())

# %%
exploracion(credito)
# Out:
# Primeros 5 registros
#   Tarjeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 0     yes                   0  37.66667   4.5200             0.033270
# 1     yes                   0  33.25000   2.4200             0.005217
# 2     yes                   0  33.66667   4.5000             0.004156
# 3     yes                   0  30.50000   2.5400             0.065214
# 4     yes                   0  32.16667   9.7867             0.067051
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 0  124.983300                     yes                     no             3
# 1    9.854167                      no                     no             3
# 2   15.000000                     yes                     no             4
# 3  137.869200                      no                     no             0
# 4  546.503300                     yes                     no             2
#
#    Meses de Historial  Tarjetas Principales  Cuentas Activas
# ...

# %%
homicidios = pd.read_csv("https://raw.githubusercontent.com/Fabian830348/Bases_Datos/master/homicidios.csv")
homicidios.head()
# Out:
#       Fecha Departamento     Municipio      Día      Hora        Barrio  \
# 0  1/1/2017     AMAZONAS  LETICIA (CT)  Domingo  15:05:00  KILOMETRO 11
# 1  1/1/2017    ANTIOQUIA       BETANIA  Domingo  21:20:00     LA CUMBRE
# 2  1/1/2017    ANTIOQUIA    COPACABANA  Domingo   4:48:00       MACHADO
# 3  1/1/2017    ANTIOQUIA       EBÉJICO  Domingo   5:00:00         SAGUA
# 4  1/1/2017    ANTIOQUIA      EL BAGRE  Domingo   6:30:00    LAS BRISAS
#
#      Zona         Clase de sitio                Arma empleada  \
# 0   RURAL              CARRETERA  ARMA BLANCA / CORTOPUNZANTE
# 1  URBANA          VIAS PUBLICAS                ARMA DE FUEGO
# 2  URBANA  DENTRO DE LA VIVIENDA  ARMA BLANCA / CORTOPUNZANTE
# 3   RURAL     FINCAS Y SIMILARES                ARMA DE FUEGO
# 4  URBANA          VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
#
#           Móvil Agresor         Móvil Victima  Edad       Sexo Estado civil  \
# 0  PASAJERO MOTOCICLETA  PASAJERO MOTOCICLETA    20  MASCULINO      SOLTERO
# ...

# %%
exploracion(homicidios)
# Out:
# Primeros 5 registros
#       Fecha Departamento     Municipio      Día      Hora        Barrio  \
# 0  1/1/2017     AMAZONAS  LETICIA (CT)  Domingo  15:05:00  KILOMETRO 11
# 1  1/1/2017    ANTIOQUIA       BETANIA  Domingo  21:20:00     LA CUMBRE
# 2  1/1/2017    ANTIOQUIA    COPACABANA  Domingo   4:48:00       MACHADO
# 3  1/1/2017    ANTIOQUIA       EBÉJICO  Domingo   5:00:00         SAGUA
# 4  1/1/2017    ANTIOQUIA      EL BAGRE  Domingo   6:30:00    LAS BRISAS
#
#      Zona         Clase de sitio                Arma empleada  \
# 0   RURAL              CARRETERA  ARMA BLANCA / CORTOPUNZANTE
# 1  URBANA          VIAS PUBLICAS                ARMA DE FUEGO
# 2  URBANA  DENTRO DE LA VIVIENDA  ARMA BLANCA / CORTOPUNZANTE
# 3   RURAL     FINCAS Y SIMILARES                ARMA DE FUEGO
# 4  URBANA          VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
#
#           Móvil Agresor         Móvil Victima  Edad       Sexo Estado civil  \
# ...

# %%
def dimensiones(df):
    return pd.DataFrame({
        "Filas": [df.shape[0]],
        "Columnas": [df.shape[1]]
    })

# %%
dimensiones(credito)
# Out:
#    Filas  Columnas
# 0   1297        12

# %%
def tipos(df):
    return pd.DataFrame({
        "Columna": df.columns,
        "Tipo": df.dtypes.values
    })

# %%
tipos(credito)
# Out:
#                     Columna     Tipo
# 0                   Tarjeta   object
# 1        Reportes Negativos    int64
# 2                      Edad  float64
# 3                   Ingreso  float64
# 4       Proporcion de Gasto  float64
# 5                     Gasto  float64
# 6   Propietario de Vivienda   object
# 7    Trabajor Independiente   object
# 8              Dependientes    int64
# 9        Meses de Historial    int64
# 10     Tarjetas Principales    int64
# 11          Cuentas Activas  float64

# %%
import pandas as pd
import numpy as np

# %%
credito = pd.read_csv("https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/credict_para_limpiar.csv")
credito.head()
# Out:
#   Trajeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 0     yes                   0  37.66667   4.5200             0.033270
# 1     yes                   0     33.25   2.4200             0.005217
# 2     yes                   0  33.66667   4.5000             0.004156
# 3     yes                   0      30.5   2.5400             0.065214
# 4     yes                   0  32.16667   9.7867             0.067051
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 0  124.983300                     yes                     no             3
# 1    9.854167                      no                     no             3
# 2   15.000000                     yes                     no             4
# 3  137.869200                      no                     no             0
# 4  546.503300                     yes                     no             2
#
#   Meses de Historial  Tarjetas Principales  Cuentas Activas
# ...

# %%
credito["Propietario de Vivienda"].unique()
# Out:
# array(['yes', 'no', nan, 'Yes', 'NO'], dtype=object)

# %%
def unicos(datos,variable):
  return datos[variable].unique()

# %%
unicos(credito,"Propietario de Vivienda")
# Out:
# array(['yes', 'no', nan, 'Yes', 'NO'], dtype=object)

# %%
def valores_unicos(df, columna):
    return pd.DataFrame({
        "Valores únicos": df[columna].unique()
    })

# %%
valores_unicos(credito, "Trajeta")
# Out:
#   Valores únicos
# 0            yes
# 1             no
# 2            Yes
# 3             No

# %%
u = pd.to_numeric(credito["Edad"], errors='coerce').isna()

# %%
u
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1314    False
# 1315    False
# 1316    False
# 1317    False
# 1318    False
# Name: Edad, Length: 1319, dtype: bool

# %%
np.where(u)[0]
# Out:
# array([ -12,  -16, -117, -570])

# %%
credito.iloc[np.where(u)[0]]
# Out:
#     Trajeta  Reportes Negativos Edad  Ingreso  Proporcion de Gasto     Gasto  \
# 11       no                   0          1.98             0.000606    0.0000
# 15      yes                   0          3.20             0.125819  335.4350
# 116     yes                   1  NaN     2.00             0.060808  101.2625
# 569     yes                   0  NaN     2.10             0.321348  562.3592
#
#     Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 11                      yes                     no             2
# 15                      yes                     no             1
# 116                     yes                     no             3
# 569                      no                     no             0
#
#     Meses de Historial  Tarjetas Principales  Cuentas Activas
# 11                  36                     1              0.0
# 15                 168                     1             22.0
# 116                 42                     1              3.0
# ...

# %%
def problema_texto(datos, variable):
  u = pd.to_numeric(datos[variable], errors='coerce').isna()
  posiciones = np.where(u)[0]
  print(posiciones)
  return datos.iloc[posiciones]

# %%
problema_texto(credito,"Meses de Historial")
# Out:
# [  2  14  32 252 320 399 465 496]
#     Trajeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 2       yes                   0  33.66667    4.500             0.004156
# 14      yes                   0  35.33333    1.908             0.026907
# 32       no                   1  24.91667    3.150             0.000381
# 252     yes                   0  25.08333    2.650             0.009651
# 320      no                   2  28.16667    2.600             0.000462
# 399     yes                   0  22.58333    2.250             0.011111
# 465      no                   0  23.83333    2.200             0.000545
# 496     yes                   0     42.25    3.235             0.024766
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 2    15.00000                     yes                     no             4
# 14   42.61500                     yes                     no             2
# ...
