# %% [markdown]
# <table>
#         <td>
#         <td><img src="https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/logo_ECI.png" width="400"/></td>
#         <td>&nbsp;</td>
#         <td>
#             <h1 style="font-size:200%;color:blue;text-align:center">    <FONT COLOR="blue"> DataFrames </p> Estructuras de Control</p> if-for-while </FONT>         </h1></td>
#         <td>
#             <tp><p style="font-size:99%;text-align:center">Diplomado Ciencia de Datos </p></tp>
#             <tp><p style="font-size:115%;text-align:center">2026-2</p></tp>
#             <tp><p style="font-size:115%;text-align:center">Prof. Fabián Sánchez</p></tp>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # <FONT SIZE=5 COLOR="purple"> 1. Estructuras de Control </FONT>
#
# Una **estructura de control** es un concepto básico de la programación (especialmente en el campo de la ciencias de la computación) que sirve para decidir cómo se ejecutan las instrucciones de un programa.
#
# En pocas palabras:
#
# - Indica en qué orden se ejecuta el código, si se repite o si se toman decisiones.
#
# - Estas estructuras de permite modificar el orden en el cual se ejecutan las instrucciones de un algoritmo.
#
# ##  <FONT SIZE=5 COLOR="green"> Tipos de estructuras de control </FONT>
#
# **1. Secuencial**
#
# Es la forma más simple: las instrucciones se ejecutan una tras otra, en orden.
#
# ```python
# leer número
# sumar 5
# mostrar resultado
# ```
#
# **2. Condicional (decisión)**
#
# Permite que el programa tome decisiones dependiendo de una condición.
#
# ```python
# si (edad >= 18)
#     mostrar "Eres mayor de edad"
# si no
#     mostrar "Eres menor de edad"
# ```
#
# **3. Repetitiva (bucles)**
#
# Sirve para repetir instrucciones varias veces.
#
# ```python
# mientras (contador < 5)
#     mostrar contador
#     contador = contador + 1
# ```
#
# **¿Para qué sirven?**
#
# Las estructuras de control permiten que un programa:
#
# - Tome decisiones
# - Repita acciones
# - Controle el flujo del programa
#
# Sin ellas, los programas solo ejecutarían instrucciones de forma lineal, sin lógica.
#
# Ejemplo
#
# ```python
# edad_maria = 56
# edad_alberto = 47
#
# # Si María es mayor en edad que Alberto entonces:
# if (edad_maria > edad_alberto):
#   print('María tiene más años que Alberto.')
# # De lo contrario:
# else:
#   print('Alberto tiene mas años que María.')
#
# ```

# %% [markdown]
# # <FONT SIZE=5 COLOR="purple"> 2. Condicional if</FONT>
#
# El condicional **if** es una estructura de control que permite que un programa tome decisiones. Evalúa una condición y, si esta es verdadera, ejecuta un bloque de instrucciones. Si la condición es falsa, ese bloque no se ejecuta (o se ejecuta otro bloque si se utiliza **else**).
#
# ```python
# if condición:
#     instrucciones
# ```
#
# Ejemplo
#
# ```python
# edad = 20
# if edad >= 18:
#     print("Eres mayor de edad")
# ```
#
# **Uso de else**
#
# Cuando queremos ejecutar una acción diferente si la condición es falsa, utilizamos *else:*
#
# ```python
# edad = 16
#
# if edad >= 18:
#     print("Eres mayor de edad")
# else:
#     print("Eres menor de edad")
# ```
#
# Las estructuras condicionales permiten que los programas reaccionen a diferentes situaciones y tomen decisiones de manera automática. Gracias al **if**, es posible validar datos, controlar accesos, comparar valores y adaptar el comportamiento del programa según las condiciones que se presenten.

# %% [markdown]
# **Ejemplo 1**

# %%
a = 3
if a > 8:
  print("Hola")
else:
  print("Adiós")
# Out:
# Adiós

# %% [markdown]
# **Ejemplo 2**

# %%
a = 15
b = 10
if a > b:
    print("a es mayor que b")
# Out:
# a es mayor que b

# %%
a = 15
b = 10
if a > b:
    print(f"{a} es mayor que {b}")
# Out:
# 15 es mayor que 10

# %% [markdown]
# **Ejemplo 3**

# %%
edad = 20
if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres mayor de edad

# %% [markdown]
# **Ejemplo 4**

# %%
temperatura = 25

if temperatura > 20:
    print("Clima agradable")
else:
    print("Hace frío")

# %% [markdown]
# Podemos combinar las instrucciones con funciones

# %% [markdown]
# **Ejemplo 5**

# %%
def clima(temperatura):
    if temperatura > 20:
        print("El clima es agradable")
    else:
        print("uyyy! Hace frío")

# %%
clima(50)
# Out:
# El clima es agradable

# %%
def clima2(temperatura):
    if temperatura > 20:
        print("Clima agradable")
    elif temperatura == 20:
        print("Clima normal")
    else:
        print("Hace frío")

# %%
clima2(-20)
# Out:
# Hace frío

# %%
clima2(100)
# Out:
# Clima agradable

# %%
clima2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1940/1279509501.py in <cell line: 0>()
# ----> 1 clima2()
#
# TypeError: clima2() missing 1 required positional argument: 'temperatura'

# %%
import pandas as pd
import numpy  as np

# %%
# cargamos los datos: apartamentos
aptos = pd.read_csv("https://raw.githubusercontent.com/Fabian830348/Bases_Datos/master/apartamentos.csv")
aptos.head()
# Out:
#    Unnamed: 0  precio    mt2 ubicacion  estrato  alcobas  banos balcon  \
# 0           1    79.0  43.16     norte        3        3      1     si
# 1           2    93.0  56.92     norte        2        2      1     si
# 2           3   100.0  66.40     norte        3        2      2     no
# 3           4   123.0  61.85     norte        2        3      2     si
# 4           5   135.0  89.80     norte        4        3      2     si
#
#   parqueadero  administracion     avaluo terminado
# 0          si           0.050  14.923002        no
# 1          si           0.069  27.000000        si
# 2          no           0.000  15.738427        no
# 3          si           0.130  27.000000        no
# 4          no           0.000  39.567000        si

# %% [markdown]
# **Ejemplo 6**

# %%
def tamano(metros2):
  if metros2 >= 80:
    return "el apartamento es grande"
  else:
    return "el apartamento es pequeño"

# %%
tamano(60)
# Out:
# 'el apartamento es pequeño'

# %%
tamano(90)
# Out:
# 'el apartamento es grande'

# %% [markdown]
# **¿Cómo aplicar una función a todos los elementos de la variable?**

# %%
# se utiliza la función apply
aptos["Tamano"] = aptos.mt2.apply(tamano)

# %%
aptos.head()
# Out:
#    Unnamed: 0  precio    mt2 ubicacion  estrato  alcobas  banos balcon  \
# 0           1    79.0  43.16     norte        3        3      1     si
# 1           2    93.0  56.92     norte        2        2      1     si
# 2           3   100.0  66.40     norte        3        2      2     no
# 3           4   123.0  61.85     norte        2        3      2     si
# 4           5   135.0  89.80     norte        4        3      2     si
#
#   parqueadero  administracion     avaluo terminado                     Tamano
# 0          si           0.050  14.923002        no  el apartamento es pequeño
# 1          si           0.069  27.000000        si  el apartamento es pequeño
# 2          no           0.000  15.738427        no  el apartamento es pequeño
# 3          si           0.130  27.000000        no  el apartamento es pequeño
# 4          no           0.000  39.567000        si   el apartamento es grande

# %% [markdown]
# Veamos algunos ejemplos con datos

# %%
aptos.precio.mean()
# Out:
# np.float64(317.7627391930836)

# %%
#Ejemplo 1
if aptos.precio.mean() > 400:
    print("El apartamento tiene un precio alto")
else:
    print("El apartamento tiene un precio bajo")
# Out:
# El apartamento tiene un precio bajo

# %% [markdown]
# **Ejemplo**

# %%
def clasificar(precio):
    if precio >= 400:
        return 'El apartamento es caro'
    elif precio < 400 and precio > 200:
        return 'El apartamento está bien'
    else:
        return 'El apartamento es barato'

# %%
aptos["clasificacion"] = aptos.precio.apply(clasificar)

# %%
aptos.head()
# Out:
#    Unnamed: 0  precio    mt2 ubicacion  estrato  alcobas  banos balcon  \
# 0           1    79.0  43.16     norte        3        3      1     si
# 1           2    93.0  56.92     norte        2        2      1     si
# 2           3   100.0  66.40     norte        3        2      2     no
# 3           4   123.0  61.85     norte        2        3      2     si
# 4           5   135.0  89.80     norte        4        3      2     si
#
#   parqueadero  administracion     avaluo terminado                     Tamano  \
# 0          si           0.050  14.923002        no  el apartamento es pequeño
# 1          si           0.069  27.000000        si  el apartamento es pequeño
# 2          no           0.000  15.738427        no  el apartamento es pequeño
# 3          si           0.130  27.000000        no  el apartamento es pequeño
# 4          no           0.000  39.567000        si   el apartamento es grande
#
#               clasificacion
# 0  El apartamento es barato
# ...

# %%
# Ejemplo 3
def aplicar_descuento(valor):
  if valor == "no":
    return "sin descuento"
  elif valor == "si":
    return "con descuento"
  else:
    return "no sé"

aptos["descuentos"] = aptos.terminado.apply(aplicar_descuento)

# %%
aptos.head()
# Out:
#    Unnamed: 0  precio    mt2 ubicacion  estrato  alcobas  banos balcon  \
# 0           1    79.0  43.16     norte        3        3      1     si
# 1           2    93.0  56.92     norte        2        2      1     si
# 2           3   100.0  66.40     norte        3        2      2     no
# 3           4   123.0  61.85     norte        2        3      2     si
# 4           5   135.0  89.80     norte        4        3      2     si
#
#   parqueadero  administracion     avaluo terminado             clasificacion  \
# 0          si           0.050  14.923002        no  El apartamento es barato
# 1          si           0.069  27.000000        si  El apartamento es barato
# 2          no           0.000  15.738427        no  El apartamento es barato
# 3          si           0.130  27.000000        no  El apartamento es barato
# 4          no           0.000  39.567000        si  El apartamento es barato
#
#     Tamano     descuentos
# 0  pequeño  sin descuento
# ...

# %%
aptos.terminado.apply(aplicar_descuento)

# %% [markdown]
# Veamos otros ejemplos

# %%
# ejemplo
# tipo de datos columnas
aptos.precio.dtype == "float64"
# Out:
# True

# %%
# ejemplo
if aptos.terminado.dtype == "object":
  print("Esta es una variable categórica")
# Out:
# Esta es una variable categórica

# %%
# ejemplo
if aptos.terminado.dtype == "object":
  print("Esta es una variable categórica")
  print(aptos.terminado.unique())
else:
  print("Esta es una variable numérica")
# Out:
# Esta es una variable categórica
# ['no' 'si']

# %% [markdown]
# También se le podría incluir otra condición a evaluar (puede ser de conjunción, disyunción y/o negación).
#
#
# ```python
# edad_maria = 56
# edad_alberto = 47
# altura_maria = 1.56
# altura_alberto = 1.70
#
# # Si María es mayor en edad que Alberto entonces:
# if (edad_maria > edad_alberto):
#   print('María tiene más años que Alberto')
#
#   if (altura_maria > altura_alberto):
#     print('Adicionalmente, es más alta que Alberto.')
#
#   else:
#     print('Sin embargo Alberto es más alto.')
#
# # De lo contrario:
# else:
#   print('Alberto tiene mas años que María.')
#
#   if (altura_maria < altura_alberto):
#     print('Adicionalmente, es más alto que María.')
#
#   else:
#     print('Sin embargo María es más alta.')
#
# ```

# %% [markdown]
# # <FONT SIZE=5 COLOR="purple"> 2. Cíclica *for* </FONT>
#
# El ciclo *for* es una estructura de control repetitiva que permite ejecutar un bloque de código varias veces. Se utiliza cuando conocemos cuántas veces queremos repetir una acción o cuando queremos recorrer los elementos de una colección (lista, cadena, DataFrame, etc.).
#
# ```python
# for variable in secuencia:
#     instrucciones
# ```

# %%
# ejemplo 1
frutas = ['manzana', 'pera', 'uva']

for fruta in frutas:
    print(fruta)
# Out:
# manzana
# pera
# uva

# %%
# ejemplo 2
for i in range(10,16):
    print(i**2)
# Out:
# 100
# 121
# 144
# 169
# 196
# 225

# %%
# ejemplo 3
suma = 0
for i in range(1, 6):
    suma = suma + i
    print(suma)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
# ejemplo 3
suma = 0
for i in range(1, 6):
    suma = suma + i

print(suma)
# Out:
# 15

# %%
# ejemplo 4
for letra in "Python":
    print(letra)
# Out:
# P
# y
# t
# h
# o
# n

# %%
# ejemplo 4
for letra in ["Python", "R" , "SAS", 78]:
    print(letra)
# Out:
# Python
# R
# SAS
# 78

# %%
for columnas in aptos.columns:
  print(f"{columnas}")  # f-string
# Out:
# Unnamed: 0
# precio
# mt2
# ubicacion
# estrato
# alcobas
# banos
# balcon
# parqueadero
# administracion
# avaluo
# terminado
# Tamano
# clasificacion

# %%
aptos.columns
# Out:
# Index(['Unnamed: 0', 'precio', 'mt2', 'ubicacion', 'estrato', 'alcobas',
#        'banos', 'balcon', 'parqueadero', 'administracion', 'avaluo',
#        'terminado', 'Tamano', 'clasificacion'],
#       dtype='object')

# %%
# ejemplo 5
for columna in aptos.columns:
    print(f"{columna}: {aptos[columna].dtype}")
# Out:
# Unnamed: 0: int64
# precio: float64
# mt2: float64
# ubicacion: object
# estrato: int64
# alcobas: int64
# banos: int64
# balcon: object
# parqueadero: object
# administracion: float64
# avaluo: float64
# terminado: object
# Tamano: object
# clasificacion: object

# %%
# ejemplo 5
for columna in aptos.columns:
  if aptos[columna].dtype == "object":
    print(f"{columna}: {aptos[columna].unique()}")
# Out:
# ubicacion: ['norte' 'occidente' 'poblado' 'aburra sur' 'belen guayabal' 'centro'
#  'laureles']
# balcon: ['si' 'no']
# parqueadero: ['si' 'no']
# terminado: ['no' 'si']
# Tamano: ['el apartamento es pequeño' 'el apartamento es grande']
# clasificacion: ['El apartamento es barato' 'El apartamento está bien'
#  'El apartamento es caro']

# %% [markdown]
# Carguemos otros datos

# %%
# cargamos los datos crédito
credito = pd.read_csv("https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/credict_para_limpiar.csv")
credito.head()
# Out:
#   Trajeta  Reportes Negativos      Edad  Ingreso  Proporcion de Gasto  \
# 0     yes                   0  37.66667   4.5200             0.033270
# 1     yes                   0     33.25   2.4200             0.005217
# 2     yes                   0  33.66667   4.5000             0.004156
# 3     yes                   0      30.5   2.5400             0.065214
# 4     yes                   0  32.16667   9.7867             0.067051
#
#         Gasto Propietario de Vivienda Trabajor Independiente  Dependientes  \
# 0  124.983300                     yes                     no             3
# 1    9.854167                      no                     no             3
# 2   15.000000                     yes                     no             4
# 3  137.869200                      no                     no             0
# 4  546.503300                     yes                     no             2
#
#   Meses de Historial  Tarjetas Principales  Cuentas Activas
# ...

# %%
# ejemplo 6
for columna in credito.columns:
    nulos = credito[columna].isnull().sum()
    print(f"{columna}: {nulos} valores nulos")
# Out:
# Trajeta: 0 valores nulos
# Reportes Negativos: 0 valores nulos
# Edad: 2 valores nulos
# Ingreso: 1 valores nulos
# Proporcion de Gasto: 1 valores nulos
# Gasto: 0 valores nulos
# Propietario de Vivienda: 1 valores nulos
# Trabajor Independiente: 2 valores nulos
# Dependientes: 0 valores nulos
# Meses de Historial: 5 valores nulos
# Tarjetas Principales: 0 valores nulos
# Cuentas Activas: 1 valores nulos

# %%
aptos.columns
# Out:
# Index(['Unnamed: 0', 'precio', 'mt2', 'ubicacion', 'estrato', 'alcobas',
#        'banos', 'balcon', 'parqueadero', 'administracion', 'avaluo',
#        'terminado', 'Tamano', 'clasificacion'],
#       dtype='object')

# %%
aptos.select_dtypes(include='object').columns
# Out:
# Index(['ubicacion', 'balcon', 'parqueadero', 'terminado', 'Tamano',
#        'clasificacion'],
#       dtype='object')

# %%
# ejemplo 7
for columna in aptos.select_dtypes(include='object').columns:
    print(f"\n{columna}")
    print(aptos[columna].unique())
# Out:
# ubicacion
# ['norte' 'occidente' 'poblado' 'aburra sur' 'belen guayabal' 'centro'
#  'laureles']
#
# balcon
# ['si' 'no']
#
# parqueadero
# ['si' 'no']
#
# terminado
# ['no' 'si']
#
# Tamano
# ['el apartamento es pequeño' 'el apartamento es grande']
#
# clasificacion
# ['El apartamento es barato' 'El apartamento está bien'
#  'El apartamento es caro']

# %%
for columna in aptos.select_dtypes(include='object').columns:
    print(f"\n{columna}\n")
    display(aptos[columna].value_counts())
# Out:
# ubicacion
# ubicacion
# poblado           268
# aburra sur        169
# laureles           73
# occidente          69
# belen guayabal     67
# centro             38
# norte              10
# Name: count, dtype: int64
# balcon
# balcon
# si    509
# no    185
# Name: count, dtype: int64
# parqueadero
# parqueadero
# si    568
# no    126
# Name: count, dtype: int64
# terminado
# terminado
# si    592
# no    102
# Name: count, dtype: int64
# Tamano
# Tamano
# el apartamento es grande     464
# el apartamento es pequeño    230
# Name: count, dtype: int64
# clasificacion
# clasificacion
# El apartamento está bien    278
# El apartamento es barato    259
# El apartamento es caro      157
# Name: count, dtype: int64

# %%
credito.columns
# Out:
# Index(['Trajeta', 'Reportes Negativos', 'Edad', 'Ingreso',
#        'Proporcion de Gasto', 'Gasto', 'Propietario de Vivienda',
#        'Trabajor Independiente', 'Dependientes', 'Meses de Historial',
#        'Tarjetas Principales', 'Cuentas Activas'],
#       dtype='object')

# %%
for columna in credito.columns:
    porcentaje = credito[columna].isna().sum() / len(credito[columna]) * 100
    if porcentaje > 0:
        print(f"{columna}: {porcentaje:.4f}% de nulos")
# Out:
# Edad: 0.1516% de nulos
# Ingreso: 0.0758% de nulos
# Proporcion de Gasto: 0.0758% de nulos
# Propietario de Vivienda: 0.0758% de nulos
# Trabajor Independiente: 0.1516% de nulos
# Meses de Historial: 0.3791% de nulos
# Cuentas Activas: 0.0758% de nulos

# %%
# datos atípicos
for columna in aptos.select_dtypes(include='number').columns:

    q1 = aptos[columna].quantile(0.25)
    q3 = aptos[columna].quantile(0.75)
    iqr = q3 - q1

    outliers = aptos[
        (aptos[columna] < q1 - 1.5*iqr) |
        (aptos[columna] > q3 + 1.5*iqr)
    ]

    print(f"{columna}: {len(outliers)} outliers")
# Out:
# Unnamed: 0: 0 outliers
# precio: 51 outliers
# mt2: 58 outliers
# estrato: 0 outliers
# alcobas: 221 outliers
# banos: 9 outliers
# administracion: 22 outliers
# avaluo: 48 outliers

# %%
import matplotlib.pyplot as plt

for columna in aptos.select_dtypes(include='number').columns:

    plt.figure(figsize=(5,3))
    plt.hist(aptos[columna])
    plt.title(columna)
    plt.show()

# %% [markdown]
# # <FONT SIZE=5 COLOR="purple"> 2. El ciclo *while* </FONT>
#
# El ciclo *while* es una estructura de control repetitiva que permite ejecutar un bloque de instrucciones mientras una condición determinada sea verdadera.
#
# A diferencia del ciclo for, que suele utilizarse cuando se conoce de antemano el número de iteraciones, el while resulta especialmente útil cuando no se sabe cuántas veces debe repetirse una acción y esta depende del cumplimiento de una condición.
#
# En cada iteración, el programa evalúa la condición y, si continúa siendo verdadera, ejecuta nuevamente el bloque de código.
#
# Por esta razón, es importante que la condición cambie en algún momento dentro del ciclo para evitar repeticiones infinitas. El uso adecuado de while permite automatizar tareas, controlar procesos iterativos y gestionar situaciones donde la repetición depende de eventos o resultados que se producen durante la ejecución del programa.
#
# ```python
# while condición:
#     instrucciones
# ```

# %%
# Ejemplo 1
contador = 1

while contador <= 3:
    print(contador)
    contador += 1
else:
    print("El ciclo ha terminado")
# Out:
# 1
# 2
# 3
# El ciclo ha terminado

# %%
# ejemplo 2
while i < len(aptos):

    if aptos.loc[i, "precio"] > 600:
        print("Valor atípico encontrado:")
        print(aptos.loc[i])
        break

    i += 1
# Out:
# Valor atípico encontrado:
# Unnamed: 0                             281
# precio                               620.0
# mt2                                  324.0
# ubicacion                          poblado
# estrato                                  6
# alcobas                                  4
# banos                                    4
# balcon                                  no
# parqueadero                             si
# administracion                        0.55
# avaluo                             338.427
# terminado                               si
# Tamano            el apartamento es grande
# clasificacion       El apartamento es caro
# Name: 280, dtype: object

# %%
def explorar_variable(datos, variable):

    print("Variable:", variable)
    print("Nulos:", datos[variable].isna().sum())

    if pd.api.types.is_numeric_dtype(datos[variable]):

        print("Tipo: Numérica")
        print(datos[variable].describe())

    else:

        print("Tipo: Categórica")
        print(datos[variable].value_counts())

# %%
explorar_variable(aptos, "terminado")
# Out:
# Variable: terminado
# Nulos: 0
# Tipo: Categórica
# terminado
# si    592
# no    102
# Name: count, dtype: int64
