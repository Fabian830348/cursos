# %% [markdown]
# <table>
#         <td>
#         <td><img src="https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/logo_ECI.png" width="400"/></td>
#         <td>&nbsp;</td>
#         <td>
#             <h1 style="font-size:200%;color:blue;text-align:center">    <FONT COLOR="blue">  DataFrames </p> Gráficas Básicas </FONT>         </h1></td>
#         <td>
#             <tp><p style="font-size:99%;text-align:center">Diplomado Ciencia de Datos</p></tp>
#             <tp><p style="font-size:115%;text-align:center">2026-2</p></tp>
#             <tp><p style="font-size:115%;text-align:center">Prof. Fabián Sánchez</p></tp>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <center><FONT SIZE=5 COLOR="magenta"> ALGUNAS GRÁFICAS ESTADÍSTICAS </FONT></center>
#
# En este notebook revisaremos algunas gráficas clásicas en cada una de las diferentes librerías: *mathplotlib* y *plotly*. También se pueden hacer gráficos elaborados en *seaborn*. Más documentación la pueden encontrar en los siguientes links.
#
# - https://matplotlib.org/
#
# - https://seaborn.pydata.org/
#
# - https://plotly.com/python/plotly-express/
#
# **Nota:** nos centraremos más en la parte gráfica y el código que en el análisis de las gráficas.

# %% [markdown]
# Cargamos la librería pandas, que nos servirá para manipulación de data.frames.

# %%
# librerías de trabajo
import pandas as pd
import numpy as np

# %%
# cargamos los datos apartamentos
aptos = pd.read_csv("https://raw.githubusercontent.com/Fabian830348/Bases_Datos/master/apartamentos.csv")
aptos.head()
# Out:
#    Unnamed: 0  precio    mt2 ubicacion  estrato  alcobas  banos balcon  \
# 0           1    79.0  43.16     norte        3        3      1     si
# 1           2    93.0  56.92     norte        2        2      1     si
# 2           3   100.0  66.40     norte        3        2      2     no
# 3           4   123.0  61.85     norte        2        3      2     si
# 4           5   135.0  89.80     norte        4        3      2     si
#
#   parqueadero  administracion     avaluo terminado
# 0          si           0.050  14.923002        no
# 1          si           0.069  27.000000        si
# 2          no           0.000  15.738427        no
# 3          si           0.130  27.000000        no
# 4          no           0.000  39.567000        si

# %%
homicidios = pd.read_csv("https://raw.githubusercontent.com/Fabian830348/Bases_Datos/master/homicidios.csv")
homicidios.head()
# Out:
#       Fecha Departamento     Municipio      Día      Hora        Barrio  \
# 0  1/1/2017     AMAZONAS  LETICIA (CT)  Domingo  15:05:00  KILOMETRO 11
# 1  1/1/2017    ANTIOQUIA       BETANIA  Domingo  21:20:00     LA CUMBRE
# 2  1/1/2017    ANTIOQUIA    COPACABANA  Domingo   4:48:00       MACHADO
# 3  1/1/2017    ANTIOQUIA       EBÉJICO  Domingo   5:00:00         SAGUA
# 4  1/1/2017    ANTIOQUIA      EL BAGRE  Domingo   6:30:00    LAS BRISAS
#
#      Zona         Clase de sitio                Arma empleada  \
# 0   RURAL              CARRETERA  ARMA BLANCA / CORTOPUNZANTE
# 1  URBANA          VIAS PUBLICAS                ARMA DE FUEGO
# 2  URBANA  DENTRO DE LA VIVIENDA  ARMA BLANCA / CORTOPUNZANTE
# 3   RURAL     FINCAS Y SIMILARES                ARMA DE FUEGO
# 4  URBANA          VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
#
#           Móvil Agresor         Móvil Victima  Edad       Sexo Estado civil  \
# 0  PASAJERO MOTOCICLETA  PASAJERO MOTOCICLETA    20  MASCULINO      SOLTERO
# ...

# %%
# cargamos el conjunto de datos hospitalización
hospital = pd.read_csv("https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/datos_hospitalizacion_3000.csv")
hoptital.head()

# %% [markdown]
# Eliminemos la variable *Unnamed: 0* que no aporta información útil al conjunto de datos.

# %%
aptos.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
aptos.head()
# Out:
#    precio    mt2 ubicacion  estrato  alcobas  banos balcon parqueadero  \
# 0    79.0  43.16     norte        3        3      1     si          si
# 1    93.0  56.92     norte        2        2      1     si          si
# 2   100.0  66.40     norte        3        2      2     no          no
# 3   123.0  61.85     norte        2        3      2     si          si
# 4   135.0  89.80     norte        4        3      2     si          no
#
#    administracion     avaluo terminado
# 0           0.050  14.923002        no
# 1           0.069  27.000000        si
# 2           0.000  15.738427        no
# 3           0.130  27.000000        no
# 4           0.000  39.567000        si

# %% [markdown]
# <center><FONT SIZE=5 COLOR="Magenta"> Mathplotlib - Seaborn - Plotly.Express </FONT></center>
#
# Existen múltiples librerías para hacer gráficas en Python. En esta parte mostraremos algunos ejemplos, sin embargo, invitamos al lector a explorar con más detalle estas librerías.
#
# - **Mathplotlib**: es una biblioteca de Python utilizada para trazar gráficos con la ayuda de otras bibliotecas como Numpy y Pandas. Es una poderosa herramienta para visualizar datos en Python. Se utiliza para crear inferencias estáticas y trazar gráficos 2D de matrices. Fue presentado por primera vez por John D. Hunter en 2002.
#
#
# - **Seaborn**: también es una biblioteca de Python que se utiliza para trazar gráficos con la ayuda de Matplotlib, Pandas y Numpy. Está construido sobre el techo de Matplotlib y se considera como un superconjunto de la biblioteca Matplotlib. Ayuda a visualizar datos univariados y bivariados.
#
# - **Plotly.express** es otra librería para visualización con gráficos interactivos que muestran algunos detalles de las gráficas.

# %% [markdown]
# Vamos a cargar las librerías

# %%
import matplotlib.pyplot  as plt
import plotly.express     as px
import seaborn            as sns

# %% [markdown]
# # <FONT SIZE=4 COLOR="green"> 1. Tabla de Frecuencias- Barras-Pie </FONT>
#
# Para hacer el gráfico de barras o de tortas haremos primero una tabla de frecuencias.
#
# - Recordemos de los gráficos de barras o de tortas se usan en general para variables categóricas o para variables cuantitativas con pocos valores, como es el caso de *número de hijos*.
#
# - En el eje $x$ van las categorías
#
# - En el eje $y$ la cantidad o frecuencia de cada clase o categoria
#
# - En los diagramas de barras las barras van separadas y de colocan de diferente color.

# %%
aptos.head()
# Out:
#    precio    mt2 ubicacion  estrato  alcobas  banos balcon parqueadero  \
# 0    79.0  43.16     norte        3        3      1     si          si
# 1    93.0  56.92     norte        2        2      1     si          si
# 2   100.0  66.40     norte        3        2      2     no          no
# 3   123.0  61.85     norte        2        3      2     si          si
# 4   135.0  89.80     norte        4        3      2     si          no
#
#    administracion     avaluo terminado
# 0           0.050  14.923002        no
# 1           0.069  27.000000        si
# 2           0.000  15.738427        no
# 3           0.130  27.000000        no
# 4           0.000  39.567000        si

# %%
# tabla de frecuencias
aptos.ubicacion.value_counts()
# Out:
# ubicacion
# poblado           268
# aburra sur        169
# laureles           73
# occidente          69
# belen guayabal     67
# centro             38
# norte              10
# Name: count, dtype: int64

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 1.1 Gráfico de Barras con Matplotlib </FONT>

# %%
# gráfico de barras de la variable ubicación con la librería matplotblib
frecuencias = aptos["ubicacion"].value_counts()
plt.bar(frecuencias.index,
        frecuencias.values)
plt.show()

# %%
plt.bar(frecuencias.index,
        frecuencias.values,
        color='green')

plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

frecuencias = aptos["ubicacion"].value_counts()

norm = mcolors.Normalize(
    vmin=frecuencias.min(),
    vmax=frecuencias.max()
)

colors = plt.cm.Purples(norm(frecuencias.values))

plt.bar(
    frecuencias.index,
    frecuencias.values,
    color=colors
)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# gráfico de barras de la variable ubicación con la librería matplotblib
frecuencias = aptos["ubicacion"].value_counts()
# Un color para cada ubicación
plt.bar(frecuencias.index,
        frecuencias.values)
# inclinar las etiquetas
plt.xticks(rotation=45)
plt.show()

# %%
colores = plt.cm.Set1(np.arange(len(frecuencias)))

plt.bar(frecuencias.index,
        frecuencias.values,
        color=colores)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# gráfico de barras de la variable ubicación con la librería matplotblib
frecuencias = aptos["ubicacion"].value_counts()
# Un color para cada ubicación
colores = plt.cm.Set2(range(len(frecuencias))) # Set1, Set2, Set3, Paired, Accent, Dark", etc.
plt.bar(frecuencias.index,
        frecuencias.values,
        color = colores)
# inclinar las etiquetas
plt.xticks(rotation=45)
plt.show()

# %%
colores = ['red', 'blue', 'green', 'orange', 'purple', 'brown']

plt.bar(frecuencias.index,
        frecuencias.values,
        color=colores)

plt.title('Frecuencia por categoría')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 1.2 Gráfico de Barras con Plotly Express </FONT>

# %%
# gráfico de barras de la variable ubicación con la librería plotly
px.bar(aptos.ubicacion.value_counts())

# %%
fig_bar = px.bar(aptos.ubicacion.value_counts())
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Exportar gráfica Plotly a HTML
fig_bar.write_html("grafica.html")

# %%
# gráfico de barras de la variable ubicación con la librería plotly
fig = px.bar(
    aptos.ubicacion.value_counts(),
    color=aptos.ubicacion.unique(),
    title="Frecuencia de apartamentos por ubicación"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 1.3 Gráfico de Pastel con Matplotlib </FONT>

# %%
# pie con la variable ubicacion y mathplotlib
frecuencias = aptos.ubicacion.value_counts()
plt.pie(frecuencias.values,
        labels=frecuencias.index)
plt.show()

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 1.4 Gráfico de Pastel con Plotly Express </FONT>

# %%
# pie con la variable ubicacion y en plotly
u = aptos.ubicacion.value_counts()
px.pie(u,
       u.index,
       u.values)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # <FONT SIZE=4 COLOR="green"> 2. Histogramas </FONT>
#
# - El histograma se usa para variables de tipo cuantitativo continuo o discreto con muchas mediciones diferentes (como la edad en ciertos casos).
#
# - En el eje $x$ se identifican las clases (intervalos) de la variable.
#
# - En el eje $y$ se identifica la frecuencia de cada una de las clases.
#
# - Las barras en el histograma quedan contiguas y además se utiliza un solo color en estas.

# %%
print(aptos.precio)
# Out:
# 0        79.0
# 1        93.0
# 2       100.0
# 3       123.0
# 4       135.0
#         ...
# 689     498.0
# 690     508.0
# 691     550.0
# 692     630.0
# 693    1350.0
# Name: precio, Length: 694, dtype: float64

# %%
# tabla de frecuencias
aptos.precio.value_counts(bins = 5)
# Out:
# (23.323999999999998, 360.0]    508
# (360.0, 695.0]                 133
# (695.0, 1030.0]                 34
# (1030.0, 1365.0]                13
# (1365.0, 1700.0]                 6
# Name: count, dtype: int64

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 2.1 Histograma con Matplotlib </FONT>

# %%
# histograma de la variable precio con matplotlib
plt.hist(aptos["precio"])
plt.show()

# %%
# Histograma de la variable precio
plt.hist(
    aptos["precio"],
    color="skyblue",      # color de relleno
    edgecolor="black",    # color del borde
    linewidth = 1.2         # grosor del borde
)

plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.title("Histograma de la variable precio")

plt.show()

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 2.1 Histograma con Plotly Express </FONT>

# %%
# solo colocar la variable
px.histogram(aptos.precio)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# histograma de la variable precio con plotly especificando
px.histogram(aptos,
             x = "precio")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(aptos,
             x = "precio")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# gráfico de histograma con edición
fig = px.histogram(aptos,
                   x="precio",
                   nbins = 30)

fig.update_traces(
    marker_color="yellow",   # color de las barras
    marker_line_color="blue",  # color del borde
    marker_line_width=1.5       # grosor del borde
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # <FONT SIZE=4 COLOR="green"> 3. Boxplot (gráfico de cajas y bigotes)</FONT>
#
# - El gráfico de caja, boxplot del inglés, fue ideado por Jhon Tukey en 1977 y es una representación estadística que resalta principalmente aspectos de la distribución de los datos u observaciones por medio de las medidas de posición.
#
# - Los diagramas de caja brindan información valiosa que no se limpia en un histograma o en un polígono de frecuencias.
#
# A continuación vamos a describir cada uno de los elementos que tiene un boxplot
#
# **La caja rectangular** : el gráfico contiene una caja rectangular. Es importante indicar que esta caja no tiene coordenadas cartesianas en el eje $X$  y las alturas en el eje $y$ no representa una escala de frecuencias. Las lineas horizontales en el diagrama de cajas describen el primer y tercer cuartil. $Q_1$ y $Q_3$ respectivamente.
#
# **Mediana** : es una línea que se muestra dentro de la caja rectangular y hace referencia al valor que divide los datos en dos partes iguales. Recuerde que la mediana es igual a $Q_2$.
#
# **Bigotes** : son líneas que salen a los costados de la caja y se usan como referencia para ubicar las observaciones que estan por fuera del $50 \%$ central de distribucion. Los bigotes nos dan información sobre la existencia de valores atípicos (*outliers*).

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 3.1 Boxplot con Matplolib </FONT>

# %%
# boxplot de la variable precio con matplotlib
plt.boxplot(aptos.precio)
plt.show()

# %%
fig = plt.boxplot(
    aptos["precio"],
    patch_artist=True,
    boxprops=dict(facecolor="yellow")
)
plt.show()

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 3.2 Boxplot con Plotly Express </FONT>

# %%
# boxplot de la variable precio con plotly
px.box(aptos.precio)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# boxplot de la variable precio con plotly
fig = px.box(aptos,
             y="precio",
             color_discrete_sequence=["purple"]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

precio = aptos["precio"]

q1 = precio.quantile(0.25)
q2 = precio.median()
q3 = precio.quantile(0.75)

iqr = q3 - q1
li = q1 - 1.5 * iqr
ls = q3 + 1.5 * iqr

fig = px.box(
    aptos,
    y="precio",
    color_discrete_sequence=["purple"]
)

# Dejar espacio a la derecha
fig.update_layout(
    margin=dict(r=180)
)

estadisticos = [
    (q1, f"Q1: {q1:,.0f}"),
    (q2, f"Mediana: {q2:,.0f}"),
    (q3, f"Q3: {q3:,.0f}"),
    (li, f"LI: {li:,.0f}"),
    (ls, f"LS: {ls:,.0f}")
]

for y, texto in estadisticos:
    fig.add_annotation(
        x=0.15,          # derecha del gráfico
        y=y,
        xref="paper",    # coordenada relativa al gráfico
        yref="y",
        text=texto,
        showarrow=False,
        align="left"
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
aptos.head()
# Out:
#    precio    mt2 ubicacion  estrato  alcobas  banos balcon parqueadero  \
# 0    79.0  43.16     norte        3        3      1     si          si
# 1    93.0  56.92     norte        2        2      1     si          si
# 2   100.0  66.40     norte        3        2      2     no          no
# 3   123.0  61.85     norte        2        3      2     si          si
# 4   135.0  89.80     norte        4        3      2     si          no
#
#    administracion     avaluo terminado
# 0           0.050  14.923002        no
# 1           0.069  27.000000        si
# 2           0.000  15.738427        no
# 3           0.130  27.000000        no
# 4           0.000  39.567000        si

# %%
fab = px.box(aptos,
       y = "precio",
       x = "ubicacion",
       color = "ubicacion")
fab.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# exportar a html fab
fab.write_html("box.html")

# %% [markdown]
# # <FONT SIZE=4 COLOR="green"> 4. Gráfico de Violin </FONT>
#
# El gráfico de violín es una herramienta de visualización utilizada para analizar la distribución de una variable numérica. Combina las características de un diagrama de caja (boxplot) con una estimación de densidad, permitiendo identificar la tendencia central, la dispersión de los datos y las regiones donde se concentran con mayor frecuencia las observaciones. Su forma facilita la detección de asimetrías, multimodalidad y posibles patrones que podrían no apreciarse claramente mediante otras representaciones gráficas, proporcionando una visión más detallada de la distribución de los datos.

# %%
# gráfico de violin
px.violin(aptos,
          x ="precio",
          color_discrete_sequence=["violet"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(aptos.precio)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(
    aptos["precio"],
    kde=True,      # curva de densidad
    bins=30
)

plt.show()

# %% [markdown]
# # <FONT SIZE=4 COLOR="green"> 5. Diagrama de Dispersión </FONT>
#
# - Los diagramas de dispersión permiten representar gráficamente dos variables cuantitativas.

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 5.1 Diagrama de Dispersión con Matplotlib </FONT>

# %%
# diagrama de dispersión con la librería matplotlib
plt.scatter(aptos.mt2,                          # variable 1
            aptos.precio,                       # variable 2
            color="blue")
plt.show()

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 5.2 Diagrama de Dispersión con Plotly Express</FONT>

# %%
# diagrama de dispersión con la librería plotly
px.scatter(aptos,
           x = "mt2",
           y = "precio",
           color_discrete_sequence=["green"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(aptos,
           x = "mt2",
           y = "precio",
           color = "parqueadero")  # variable sea categóricas
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(aptos,
                 x="mt2",
                 y="precio",
                 color="ubicacion",
                 size = "avaluo"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # <FONT SIZE=4 COLOR="green"> 6. Otros gráficos </FONT>

# %% [markdown]
# **Boxplot por cada categoria de una variable cualitativa**

# %%
px.box(aptos.precio)

# %%
px.box(aptos,
       y =  "precio",          # variable numérica
       x =  "ubicacion",       # variable categórica
       color = "ubicacion")    # color por la variable categórica
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Para guardar la imagen**

# %%
boxplot = px.box(aptos,                                 # nombre de los datos
       y = "precio",                                    # variable cuantitativa
       x = "ubicacion",                                 # variable cualitativa o categórica
       title = "Boxplot variable precio vs ubicación",  # título del gráfico
       color =  "ubicacion")                            # color por la variable categórica

boxplot.write_html("box.html") # para guardar la imagen

# %% [markdown]
# **Diagrama de dispersión con cruces de otras variables**

# %%
px.scatter(aptos,
           x= "mt2",
           y= "precio",
           color = "ubicacion")          # categórica
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(aptos,
           x= "mt2",
           y= "precio",
           color = "ubicacion",
           size = "administracion")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.scatter(aptos,
           x= "mt2",
           y= "precio",
           size = "administracion",   # el tamaño: variable numérica
           color = "ubicacion",       # categórica
           symbol= "balcon")          # categórica
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Gráfico con más edición**

# %%
# diagrama de dispersión con color de acuerdo con categorías de una variable categórica
fig = px.scatter(aptos,                                     # datos
                 x= "precio",                               # variable 1
                 y= "mt2",                                  # variable 2
                 color = "ubicacion")                       # color por categoría

fig.update_layout(yaxis_title='precio',                              # título del eje y
                  xaxis_title = "metros cuadrados",                  # título del eje x
                  title = "Diagrama de dispersión: precio vs mt2"    # título del gráfico
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Gráfico polar**

# %%
# gráfico polar frecuencias
fig = px.line_polar(aptos,
                    r = 'mt2',
                    theta = 'ubicacion',
                    line_close = True,
                    color_discrete_sequence = ['magenta'])

fig.update_traces(fill = "toself")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# mapa de calor y guardar en html
fig = px.density_heatmap(aptos,
                         x="precio",
                         y="ubicacion")
fig.show()
fig.write_html("mapa_de_calor.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # <FONT SIZE=4 COLOR="purple"> 5. Gráficos con Sweetviz </FONT>
#
# - *SWEETVIZ* es una librería para generar un resumen de los datos de forma rápida y en *html*.

# %%
# !pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 55.2 MB/s eta 0:00:00
# ...

# %%
import sweetviz as sw

# %%
reporte=sw.analyze(aptos,
                   target_feat="precio")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
from IPython.display import HTML
reporte.show_html()
HTML("SWEETVIZ_REPORT2.html")
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# SWEETVIZ_REPORT2.html

# %%
homicidios.head()
# Out:
#       Fecha Departamento     Municipio      Día      Hora        Barrio  \
# 0  1/1/2017     AMAZONAS  LETICIA (CT)  Domingo  15:05:00  KILOMETRO 11
# 1  1/1/2017    ANTIOQUIA       BETANIA  Domingo  21:20:00     LA CUMBRE
# 2  1/1/2017    ANTIOQUIA    COPACABANA  Domingo   4:48:00       MACHADO
# 3  1/1/2017    ANTIOQUIA       EBÉJICO  Domingo   5:00:00         SAGUA
# 4  1/1/2017    ANTIOQUIA      EL BAGRE  Domingo   6:30:00    LAS BRISAS
#
#      Zona         Clase de sitio                Arma empleada  \
# 0   RURAL              CARRETERA  ARMA BLANCA / CORTOPUNZANTE
# 1  URBANA          VIAS PUBLICAS                ARMA DE FUEGO
# 2  URBANA  DENTRO DE LA VIVIENDA  ARMA BLANCA / CORTOPUNZANTE
# 3   RURAL     FINCAS Y SIMILARES                ARMA DE FUEGO
# 4  URBANA          VIAS PUBLICAS  ARMA BLANCA / CORTOPUNZANTE
#
#           Móvil Agresor         Móvil Victima  Edad       Sexo Estado civil  \
# 0  PASAJERO MOTOCICLETA  PASAJERO MOTOCICLETA    20  MASCULINO      SOLTERO
# ...

# %%
reporte=sw.analyze(homicidios,
                   target_feat="Edad")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
from IPython.display import HTML
reporte.show_html()
HTML("SWEETVIZ_REPORT.html")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = aptos[["precio", "mt2", "avaluo", "administracion"]]

# with regression
sns.pairplot(df, kind="reg")
plt.show()

# without regression
sns.pairplot(df, kind="scatter")
plt.show()

# %%
aptos
# Out:
#      precio     mt2 ubicacion  estrato  alcobas  banos balcon parqueadero  \
# 0      79.0   43.16     norte        3        3      1     si          si
# 1      93.0   56.92     norte        2        2      1     si          si
# 2     100.0   66.40     norte        3        2      2     no          no
# 3     123.0   61.85     norte        2        3      2     si          si
# 4     135.0   89.80     norte        4        3      2     si          no
# ..      ...     ...       ...      ...      ...    ...    ...         ...
# 689   498.0  180.00  laureles        5        4      3     si          si
# 690   508.0  209.00  laureles        6        4      3     si          si
# 691   550.0  149.00  laureles        6        3      4     no          si
# 692   630.0  179.00  laureles        5        3      3     si          si
# 693  1350.0  494.00  laureles        5        3      4     si          si
#
#      administracion      avaluo terminado
# ...

# %%
# library & dataset
import matplotlib.pyplot as plt
import seaborn as sns
df = aptos[["precio", "mt2", "avaluo", "administracion", "parqueadero"]]

# left
sns.pairplot(df, kind="scatter", hue="parqueadero", markers=["o", "s"], palette="Set3")
plt.show()

# right: you can give other arguments with plot_kws.
sns.pairplot(df, kind="scatter", hue="parqueadero", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()
