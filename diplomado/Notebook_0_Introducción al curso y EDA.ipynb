# %%
# %%html
# <center><marquee style='width: 90%; color: blue;'><b>✌ ¡Hola a todos! Un saludo... Bienvenidos al curso Machine Learning ✌ </b></marquee><center>
# Out:
# <center><marquee style='width: 90%; color: blue;'><b>✌ ¡Hola a todos! Un saludo... Bienvenidos al curso Machine Learning ✌ </b></marquee><center>

# %% [markdown]
# <table>
#     <tr>
#         <td><img src="https://raw.githubusercontent.com/Fabian830348/Bases_Datos/refs/heads/master/Logo_EICT_horizontal_ESPANOL%20(1).png" width="300"/></td>
#         <td>&nbsp;</td>
#         <td>
#             <h1 style="font-size:200%;color:blue;text-align:center">    <FONT COLOR="blue"> Generalidades del Modulo </p> Conceptos </p> EDA   </FONT>         </h1></td>
#         <td>
#             <tp><p style="font-size:99%;text-align:center">Machine Learning </p></tp>
#             <tp><p style="font-size:115%;text-align:center">A. Supervisado</p></tp>
#             <tp><p style="font-size:115%;text-align:center">Prof. Fabián Sánchez</p></tp>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <FONT SIZE=4 COLOR="blue"> Objetivo del notebook </FONT>
#
# En esta sesión se presentarán:
#
# * Introducción al machine learning
# * Conceptos generales
# * Preprocesamiento de Datos:
#     - Carga de datos
#     - Exploración de datos (EDA)
#
# **Profesor**: Fabián Sánchez Salazar
#
# *fabian.sanchez@urosario.edu.co*

# %% [markdown]
# # <FONT SIZE=5 COLOR="Purple"> Conceptos Generales </FONT>
#
# A continuación, presentaremos los conceptos de Inteligencia Artificial (AI), Machine Learning (ML) y Deep Learning (DL).
#
#
# <br>
# <center><FONT SIZE=5 COLOR="green"> AI-ML-DL </FONT></center>
# <br>
#
# - ***Inteligencia Artificial:*** es una combinación de algoritmos y dispositivos, diseñados con el fin de crear máquinas que imiten capacidades del ser humano.
#
# - ***Machine Learning:*** es un campo de la Inteligencia Artificial que a través de algoritmos trata de identificar patrones en conjuntos de datos masivos y hacer predicciones sobre estos conjuntos.
#
# - ***Deep Learning:*** son algoritmos que usan arquitecturas computacionalmente más complejas, como las redes neuronales, para procesar y hacer predicciones sobre conjuntos de datos.
#
# El siguiente gráfico presenta la relación entre los campos definidos anteriormente.
#
# <br>
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/IA_ML_DL.png?raw=true" alt="centered image" width="700" height="450"></center><center><figcaption> <FONT SIZE=1 COLOR="black"> Fuente: Elaboración Propia  </FONT> <figcaption></center>
# <br>

# %% [markdown]
# # <FONT SIZE=4 COLOR="green"> Machine Learning </FONT>
#
# - El *Machine Learning* o aprendizaje automático de máquina trata de generar conocimiento de los datos. Es decir, extraer información oculta de los datos.
#
# - Es un campo de investigación que intersecta la estadística, inteligencia artificial y ciencias de la computación.
#
# - Las aplicaciones del *Machine Learning* están presenten en muchos contextos de la vida diaria. Desde recomendaciones automáticas de cuáles películas ver, qué comida pedir, cuáles productos comprar, hasta el reconocimiento de amigos en tus fotos.
#
# - Al mirar un sitio web complejo como Facebook, Amazon o Netflix, es muy probable que cada parte del sitio contenga múltiples modelos de machine learning.
#
# Dentro del campo del machine learning se estudian algunos tipos de problemas.
#
# ### <FONT SIZE=4 COLOR="green"> Aprendizaje supervisado </FONT>
#
# En este caso se desea automatizar el proceso de toma de decisiones a partir de ejemplos conocidos. Estos algoritmos de *Machine Learning* aprenden de los pares input/output conocidos, para crear un **output** para un **input** que nunca ha visto antes sin más ayuda.
#
# Vamos a considerar dos conjuntos de datos:
#
# 1. (**Clasificación**) Supongamos que tenemos estos datos
#
# <br>
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/supervisado5.png?raw=true" alt="centered image" width="700" height="200"></center>
# <br>
#
# donde,
#
# - ***Pregnancies***: Número de embarazos que ha tenido en su vida
# - ***Glucose***: Nivel de concentración de glucosa en sangre
# - ***BloodPressure***: Presión arterial
# - ***SkinThikness***: Espesor de piel a la altura del triceps
# - ***Insulin***: Respuesta a dosis de insulina en 2 horas
# - ***BMI***: Índice de masa corporal
# - ***DiabetesPedigreeFunction***: Presencia de diabetes en ascendencia directa
# - ***Age***: Edad del paciente
# - ***Outcome***: Variable que queremos predecir:
#    - $1$ : Tiene diabetes
#    - $0$ : No tiene diabetes
#
# ***Problema***: Predecir si una mujer, con ciertos valores en las variables antes mencionadas tiene o no diabetes.
#
# 2. (**Regresión**) Los siguientes datos contienen la información de en pauta publicitaria en diferentes medios (en miles de dólares)
#
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/supervisado4.png?raw=true" alt="centered image" width="600" height="200"></center>
#
# ***Problema***: Predecir las ventas en función de las inversiones que se hacen en pauta publicitaria en cada categoria.
#
# Algunos ejemplos de aplicaciones del aprendizaje supervisado
#
# 1. **Clasificación de correos spam**: El modelo de *Machine Learning* utiliza un algoritmo dotado de una gran cantidad de correos electrónicos (los inputs), junto con información sobre si alguno de estos correos electrónicos es spam (objetivo deseado). Dado un nuevo correo electrónico, el algoritmo producirá una predicción sobre si el nuevo correo electrónico es correo no deseado.
#
# 2. **Determinar si un tumor es benigno en base a una imagen médica:** La entrada es la imagen y la salida es si el tumor es benigno. Para crear un conjunto de datos que permita generar un modelo, se necesita una base de datos de imágenes médicas. Así mismo se necesita la opinión y conocimiento de un experto, por lo que un médico debe observar todas las imágenes y decidir qué tumores son benignos y cuáles no. Incluso podría ser necesario hacer un diagnóstico adicional más allá del contenido de la imagen para determinar si el tumor en la imagen es canceroso o no.
#
# 3. **Detección de actividad fraudulenta en transacciones con tarjetas de crédito** La entrada es un registro de la transacción de la tarjeta de crédito y la salida es si es probable que sea fraudulento o no. Suponiendo que usted es la entidad que distribuye las tarjetas de crédito, recopilar un conjunto de datos significa almacenar todas las transacciones y registro si un usuario reporta alguna transacción como fraudulenta.
#
# 4. **Predicción del comsumo de tarjeta de crédito** Con base a diferentes variables que representan las características de un cliente, se puede predecir su consumo de tarjeta de crédito en un determinado mes o periodo de tiempo.
#
# Por otra parte
#
# ### <FONT SIZE=4 COLOR="green"> Aprendizaje No Supervisado </FONT>
#
# Son algoritmos en el que solo se conocen los datos de entrada y no se conoce la salida o etiqueta.
#
# (**Clustering**) En los siguientes datos se muestra información de asesinatos, asaltos, tamaño de la población, violaciones, etc., de estados de EEUU.
#
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/no_supervisado1.png?raw=true" alt="centered image" width="500" height="200"></center>
#
# **Problema**: Identificar grupos de elementos del conjunto que compartan ciertas características.
#
# También se aplica para reducción de dimensionalidad.
#
# Algunos ejemplos de aplicación:
#
# 1. **Segmentación de clientes en grupos con preferencias similares:** Dado un conjunto de registros de clientes, es posible que desee identificar qué clientes son similares, y si hay grupos de clientes con preferencias similares.
#
# 2. **Identificar temas en un conjunto de publicaciones de blog:** Si tiene una gran colección de datos de texto, es posible que desee resumirlos y encontrar temas predominantes en él. Es posible que no sepa de antemano cuáles son estos temas, o cuántos temas puede haber. Por lo tanto, no hay salidas conocidas.
#
# <center><FONT SIZE=5 COLOR="PURPLE"> MACHINE LEARNING </FONT></center>
#
# <br>
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/imagen_ML.png?raw=true" alt="centered image" width="600" height="350"></center><center><figcaption> <FONT SIZE=1 COLOR="black"> Fuente: Elaboración propia  </FONT> <figcaption></center>
# <br>
#
# Observe que para entender y poder determinar si un problema es supervisado o no supervisado debemos tener claro el problema que debemos resolver y qué tipos de variables contiene el conjunto de datos.
#
# Un aspecto importante en el campo del Machine Learning, es que antes de aplicar cualquier modelo, se requiere conocer los datos y alistarlos.
#
# A continuación, revisaremos algunos de estos conceptos.

# %% [markdown]
# # <FONT SIZE=5 COLOR="Purple"> Proceso EDA : Exploratory Data Analysis </FONT>
#
# El ***EDA*** es el proceso mediante el cual se exploran los datos e incluye algunos pasos como lo indica el siguiente gráfico.
#
# <center><FONT SIZE=5 COLOR="PURPLE"> PROCESO DE EXPLORACIÓN DE LOS DATOS </FONT></center>
#
# <br>
#
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/imagen_eda.png?raw=true" alt="centered image" width="550" height="350"></center><center><figcaption> <FONT SIZE=1 COLOR="black"> Fuente: Elaboración propia </FONT> <figcaption></center>
#
# En el gráfico anterior se muestran algunas etapas fundamentales:
#
# 1.	**Preguntas para responder**. Es importante tener claro para qué queremos hacer el procesamiento y análisis de datos. Es decir, qué buscamos responder.
#
# 2.	**Generalidades del conjunto de datos**.  Acá buscamos reconocer la dimensión, datos faltantes, y en general un resumen general del dataset.
#
# 3.	**Tipos de Variables**. Clasificar las variables en cualitativas y cuantitativas y examinar como se presenta esta información. Por ejemplo, una variable puede estar codificada y verse como numérica, pero ser categórica.
#
# 4.	**Estadística Descriptiva**. Se busca resumir la información. Utilizar medidas de tendencia, de dispersión, de forma, de posición, etc., para entender mejor los datos. Por ejemplo, se identifican datos atípicos usando boxplot.
#
# 5.	**Visualización**.  Es una etapa fundamental en el análisis de datos. Visualizar la información y poder describirla gráficamente. En esta etapa se usan: diagramas de barras, pie, boxplot, histogramas, líneas de densidad, diagramas de dispersión, entre otros.
#
# 6.	**Relación entre variable**. Se explora datos bivariados. Se examinan relaciones entre variables cualitativas (tablas de contingencia) y relaciones entre variables cuantitativas (diagramas de dispersión) se establecen posibles relaciones lineales.
#
# 7.	**Reporte de resultados**. Una vez se haga el proceso de exploración y análisis en RStudio se deben reportar los resultados y conclusiones de lo que se encontró en la base de datos.

# %% [markdown]
# <center><FONT SIZE=6 COLOR="magenta"> PYTHON </FONT></center>
#
# Python es un lenguaje de programación de propósito general, usado ampliamente para
#
# *  Desarrollo de aplicaciones
# *  Desarrollo web
# *  Web Scraping
# *  **Ciencia de Datos**
# *  **Visualización**
# *  Aplicaciones a los negocios
# *  **Machine Learning**
# *  **Deep Learning**
#
# Python cuenta con librerías especializadas dependiendo del tipo de tarea. Algunas de ellas son:
#
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/librerias.png?raw=true" alt="centered image" width="550" height="350"></center> <center><figcaption> <FONT SIZE=1 COLOR="black"> Fuente: https://www.actumlogos.com/python-para-ia.html  </FONT> <figcaption></center>
#
# 1.   **Pandas:** manipulación de datos-estadísticas-data.frames
# 2.   **Matplotlib**: visualización-gráficas
# 3.   **numpy**: operaciones matemáticas
# 4.   **spicy**: realizar cálculo simbólico
# 5.   **scikit-learn**: ejecutar algoritmos de machine learning
# 6.   **NTKL**: Procesamiento de Lenguaje Natural.
# 7.   **seaborn**: creación de gráficos estadísticos
# 8.   **Datetime**: para manipulación de fechas

# %% [markdown]
# <center><FONT SIZE=5 COLOR="GREEN"> EXPLORACIÓN DE DATOS EN PYTHON</FONT></center>

# %% [markdown]
# <center><img src="https://miro.medium.com/v2/resize:fit:720/format:webp/0*fto5mNElXLZ8TCZr.png" alt="centered image" width="500" height="250"></center>
#
# + Librería de Python especializada manipulación y análisis de estructuras de datos
# + Permite leer datos en diferentes formatos: csv, excel, bases de datos SQL.
# + Realiza operaciones rápidas y eficientes sobre conjuntos de datos
# + Permite trabajar series de tiempo
# + *import pandas as pd*
# + [Guía Pandas](https://aprendeconalf.es/docencia/python/manual/pandas/)
#
# # <FONT SIZE=5 COLOR="red"> DataFrames </FONT>
#
# Los tipos de datos que vamos a trabajar se denominan ***Data.Frames*** y se caracterizan por tener una distribución de datos en fila y columna.
#
# <center><FONT SIZE=5 COLOR="blue"> data.frame </FONT></center>
#
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/dataframe.png?raw=true" alt="centered image" width="600" height="300"></center>
#
# Observe que un data.frame puede tener diferentes tipos de variables
#
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/tiposvariables.png?raw=true" alt="centered image" width="600" height="400"></center>
#
#
# <FONT SIZE=3 COLOR="magenta"> Algunas funciones para explorar data.frames </FONT>
#
#
# **df.info()** : Devuelve información (número de filas, número de columnas, índices, tipo de las columnas y memoria usado) sobre el DataFrame df.
#
# **df.shape** : Devuelve una tupla con el número de filas y columnas del DataFrame df.
#
# **df.size** : Devuelve el número de elementos del DataFrame.
#
# **df.columns** : Devuelve una lista con los nombres de las columnas del DataFrame df.
#
# **df.index** : Devuelve una lista con los nombres de las filas del DataFrame df.
#
# **df.dtypes** : Devuelve una serie con los tipos de datos de las columnas del DataFrame df.
#
# **df.head(n)** : Devuelve las n primeras filas del DataFrame df.
#
# **df.tail(n)** : Devuelve las n últimas filas del DataFrame df.

# %% [markdown]
# # <FONT SIZE=5 COLOR="Purple"> Ejemplo de Análisis Exploratorio de los Datos </FONT>
#
# En lo que sigue vamos a trabajar con el conjunto de datos *diabetes*.
#
# Vamos a seguir los siguientes pasos.

# %% [markdown]
# # <FONT SIZE=4 COLOR="Green"> 1. Cargar los datos </FONT>
#
# Vamos a cargar los datos desde un repositorio de *github*.
#
# Lo primero que haremos es cargar la librería **pandas**, que nos servirá para manipulación de data.frames.

# %%
#para importar la librería pandas.
import pandas as pd

# %% [markdown]
# La dirección del conjunto de datos es:
#
# ```python
# https://raw.githubusercontent.com/Fabian830348/Bases_Datos/master/diabetes.csv
# ```

# %%
url = "https://raw.githubusercontent.com/Fabian830348/Bases_Datos/master/diabetes.csv"

# %% [markdown]
# Como los datos están en formato *.csv* usamos la función:
#
# $$pd.read\_csv()$$

# %%
diabetes= pd.read_csv(url)

# %%
diabetes

# %% [markdown]
# # <FONT SIZE=5 COLOR="green"> 2. Exploración de los datos </FONT>
#
# Vamos a trabajar con este último conjunto de datos para hacer una exploración y revisar algunas instrucciones de pandas y gráficas clásicas.

# %% [markdown]
# 1. Usamos la instrucción **head()** para explorar la cabeza de los datos
#
# - Podemos indicar cuántos datos queremos visualizar simplemente con $head(n)$, sonde $n$ indica el número de registros que queremos ver.

# %%
# para visualizar los primeros datos.
diabetes.head(5)

# %% [markdown]
# 2. Usamos la instrucción **tail()** para explorar los últimos datos

# %%
# para visualizar los últimos datos.
diabetes.tail(6)

# %% [markdown]
# 3. Con la instrucción **shape** miramos el tamaño de nuestros datos

# %%
# tamaño de los datos
diabetes.shape

# %% [markdown]
# es decir, el conjunto de datos tiene 768 registros o filas y 9 columnas.

# %% [markdown]
# 4. Para explorar nombre de las variables o columnas **columns**

# %%
# columnas del conjunto de datos
diabetes.columns

# %% [markdown]
# Recordemos que significan las variables:
#
# - ***Pregnancies***: Número de embarazos que ha tenido en su vida
# - ***Glucose***: Nivel de concentración de glucosa en sangre
# - ***BloodPressure***: Presión arterial
# - ***SkinThikness***: Espesor de piel a la altura del triceps
# - ***Insulin***: Respuesta a dosis de insulina en 2 horas
# - ***BMI***: Índice de masa corporal
# - ***DiabetesPedigreeFunction***: Presencia de diabetes en ascendencia directa
# - ***Age***: Edad del paciente
# - ***Outcome***: Variable que queremos predecir:
#    - $1$ : Tiene diabetes
#    - $0$ : No tiene diabetes

# %% [markdown]
# 5. **info()** es un resumen de las variables y su clasificación. Además, podemos identificar datos faltantes (NA) en cada una de ellas.

# %%
# información de los datos
diabetes.info()

# %% [markdown]
# Es importante verificar que las variables del conjunto de datos hayan sido cargadas en el tipo adecuado, es decir, la variable.

# %% [markdown]
# 6. Para revisar las estadísticas generales de las variables cuantitativas usamos **describe()**

# %%
diabetes.describe()

# %% [markdown]
# ***Nota:*** Siempre que hagamos una tabla o gráfica es importante indicar qué queremos resaltar sobre la información contenida. Por ejemplo, en la tabla anterior podriamos indicar:
#
# *Se puede observar que el valor mínimo de glucosa reportada es 0 y el máximo es 199. con un promedio de 120*

# %%
# si queremos las estadísticas (frecuencias) de las variables cualitativas
#datos.describe(include='object')

# %% [markdown]
# 7. Para acceder a una o varias variable del data.frame podemos usar la instrucción
#
# *datos.["nombre de la variable"]*
#
# veamos algunos ejemplos

# %%
# podemos acceder a una o más variables del data.frame data[]
diabetes["Insulin"]

# %%
# podemos revisar unas estadísticas básicas de una variable numérica con .describe()
diabetes["Insulin"].describe()

# %% [markdown]
# También se puede acceder al nombre de una variable asi:
# $$datos.variable$$

# %%
diabetes.Insulin

# %% [markdown]
# # <FONT SIZE=5 COLOR="green"> 3. Tabla de frecuencias </FONT>
#
# Para hacer el conteo de las categorías o clases de una variables podemos usar la instrucción ***.value_counts***

# %% [markdown]
# Ejemplo: Para hacer una tabla de frecuencias de la variable *Pregnancies*

# %%
freq=diabetes["Outcome"].value_counts()
freq

# %% [markdown]
# # <FONT SIZE=4 COLOR="purple"> 4. Algunas Gráficas Clásicas </FONT>
#
# En esta sección revisaremos algunas gráficas clásicas.
#
# Para esto podemos usar diferentes librerías: *mathplotlib* y *plotly*. También se pueden hacer gráficos elaborados en *seaborn* Más documentación la pueden encontrar en los siguientes links.
#
# - https://matplotlib.org/
#
# - https://seaborn.pydata.org/
#
# - https://plotly.com/python/plotly-express/
#
# **Nota:** nos centraremos más en la parte gráfica y el código que en el análisis de las gráficas.

# %% [markdown]
# <center><FONT SIZE=5 COLOR="Magenta"> Mathplotlib - Seaborn - Plotly.Express </FONT></center>
#
# Existen múltiples librerías para hacer gráficas en Python. En esta parte mostraremos algunos ejemplos, sin embargo, invitamos al lector a explorar con más detalle estas librerías.
#
# - **Mathplotlib**: es una biblioteca de Python utilizada para trazar gráficos con la ayuda de otras bibliotecas como Numpy y Pandas. Es una poderosa herramienta para visualizar datos en Python. Se utiliza para crear inferencias estáticas y trazar gráficos 2D de matrices. Fue presentado por primera vez por John D. Hunter en 2002.
#
#
# - **Seaborn**: también es una biblioteca de Python que se utiliza para trazar gráficos con la ayuda de Matplotlib, Pandas y Numpy. Está construido sobre el techo de Matplotlib y se considera como un superconjunto de la biblioteca Matplotlib. Ayuda a visualizar datos univariados y bivariados.
#
# - **Plotly.express** es otra librería para visualización con gráficos interactivos que muestran algunos detalles de las gráficas.

# %% [markdown]
# Vamos a cargar las librerías

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sb

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 4.1. TABLA DE FRECUENCIA - BARRAS Y TORTAS </FONT>
#
# Para hacer el gráfico de barras o de tortas haremos primero una tabla de frecuencias.
#
# - Recordemos de los gráficos de barras o de tortas se usan en general para variables categóricas o para variables cuantitativas con pocos valores, como es el caso de *número de hijos*.
#
# - En el eje $x$ van las categorías
#
# - En el eje $y$ la cantidad o frecuencia de cada clase o categoria
#
# - En los diagramas de barras las barras van separadas y de colocan de diferente color.

# %% [markdown]
# Para la variable "Outcome" hacer:
#
# - Tabla de frecuencias
# - Gráfico de barras
# - Diagrama de tortas

# %%
freq=diabetes["Outcome"].value_counts()
freq

# %% [markdown]
# ### <FONT SIZE=4 COLOR="blue"> Gráfico de barras </FONT>

# %%
# gráfico de barras
px.bar(freq)

# %% [markdown]
# ¿Qué podemos decir del gráfico anterior?

# %% [markdown]
# ### <FONT SIZE=4 COLOR="blue"> Gráfico de Tortas </FONT>

# %%
# diagrama de tortas
px.pie(freq,
       values= freq,
       names = freq)

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 4.2 HISTOGRAMAS  </FONT>
#
# - El histograma se usa para variables de tipo cuantitativo continuo o discreto con muchas mediciones diferentes (como la edad en ciertos casos).
#
# - En el eje $x$ se identifican las clases (intervalos) de la variable.
#
# - En el eje $y$ se identifica la frecuencia de cada una de las clases.
#
# - Las barras en el histograma quedan contiguas y además se utiliza un solo color en estas.

# %%
# histograma
px.histogram(diabetes.BloodPressure)

# %% [markdown]
# Podemos usar un poco más de edición

# %%
fig = px.histogram(diabetes.BloodPressure,                  # variable
                   nbins = 30,                              # número de intervalos
                   x = "BloodPressure",                     # nombre de la variable x
                   title = "Histograma con edición"         # título del gráfico
                                      )

fig.update_traces(marker_color = 'cyan',                    # color de relleno
                  marker_line_color = 'red',                # color del borde
                  marker_line_width = 1,                    # grueso de la línea
                  opacity = 1)                              # transparencia del color

fig.show()

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 4.3. BOXPLOT (GRÁFICO DE CAJAS Y BIGOTES) </FONT>
#
# - El gráfico de caja, boxplot del inglés, fue ideado por Jhon Tukey en 1977 y es una representación estadística que resalta principalmente aspectos de la distribución de los datos u observaciones por medio de las medidas de posición.
#
# - Los diagramas de caja brindan información valiosa que no se limpia en un histograma o en un polígono de frecuencias.
#
# A continuación a describir cada uno de los elementos que tiene un boxplot
#
# **La caja rectangular** : el gráfico contiene una caja rectangular. Es importante indicar que esta caja no tiene coordenadas cartesianas en el eje $X$  y las alturas en el eje $y$ no representa una escala de frecuencias. Las lineas horizontales en el diagrama de cajas describen el primer y tercer cuartil. $Q_1$ y $Q_3$ respectivamente.
#
# **Mediana** : es una línea que se muestra dentro de la caja rectangular y hace referencia al valor que divide los datos en dos partes iguales. Recuerde que la mediana es igual a $Q_2$.
#
# **Bigotes** : son lineas que salen a los costados de la caja y se usan como referencia para ubicar las observaciones que estan por fuera del $50 \%$ central de distribucion. Los bigotes nos dan información sobre la existencia de valores atípicos (*outliers*).

# %%
# Diagrama de cajas
px.box(diabetes.Insulin)

# %%
# Diagrama de cajas
px.box(diabetes.Age)

# %%
px.box(diabetes,                                           # nombre de los datos
       y = "Age",                                          # variable cuantitativa
       x = "Pregnancies",                                  # variable cualitativa o categórica
       title = "Boxplot variable Age vs Pregnancies",      # título
       color = "Pregnancies"                               # color por la variable categórica
             )

# %% [markdown]
# ## <FONT SIZE=4 COLOR="green"> 4.4 DIAGRAMA DE DISPERSIÓN </FONT>
#
# - Los diagramas de dispersión permiten representar graficamente dos variables cuantitativas.

# %%
diabetes.head()

# %%
px.scatter(diabetes,
           x= "Glucose",
           y= "BloodPressure")

# %%
px.scatter(diabetes,
           x= "Glucose",
           y= "BMI",
           color = "Outcome")

# %%
sb.pairplot(diabetes)

# %% [markdown]
# # <FONT SIZE=5 COLOR="green"> 5. Manipulación de DataFrame </FONT>
#
# En esta sección revisaremos algunas operaciones u acciones que son importantes de conocer en un Data.Frame:
#
# - Ordenar por una variable
#
# - Renombrar una variable
#
# - Eliminar una variable
#
# - Agregar una variable
#
# - Agrupar por categorias de una variable y aplicar funciones.
#
# Para repasar
#
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# ## <FONT SIZE=4 COLOR="magenta"> 5.1 Ordenar según una variable </FONT>
#
# Para ordenar por una variable usamos la instrucción
#
# $$datos.sort\_values(variable, ascending = False) $$
#
# se usa:
#
# - *ascending=True* :  ordena de menor a mayor.
# - *ascending=False* : ordena de mayor a menor.

# %%
# ordenamos por la variable Edad de menor a mayor
diabetes.sort_values("Age" , ascending =  False)

# %% [markdown]
# ## <FONT SIZE=4 COLOR="magenta"> 5.2 Renombrar una variable </FONT>
#
# Podemos renombrar una columna de la siguiente forma usando la instrucción ***rename***
#
# $$ datos.rename(columns=\{key : value, key : value\}, inplace=True) $$
#
#  - Para cambiar el nombre de una variable debemos usar un diccionario donde las claves son las variables actuales y los valores son los nombres nuevos de las variables.
#  - Recordemos que la instrucción **inplace** se usa para determinar si cambiamos el DataFrame original.

# %%
# cambiaremos el nombre de administracion por admon
diabetes.rename(columns={"Outcome" : "diabetes"}, inplace=False)

# %% [markdown]
# ## <FONT SIZE=4 COLOR="magenta"> 5.3 Eliminar filas y columnas</FONT>
#
# Para eliminar una columna o una fila usamos la instrucción .drop
#
# $$datos.drop(``nombre", axis = 1, inplace = T \, or \, F)$$
#
# - *axis = 1* : es por columna
# - *axis = 0* : es por  fila
# - *inplace = T* : sobreescribe en el *df* original.
# - *inplace = F* : no sobreescribe. Mantiene el original

# %%
diabetes_copy = diabetes.copy()

# %%
# axis = 1
diabetes_copy.drop("Pregnancies", axis = 1 , inplace = True)

# %%
diabetes_copy.head()

# %% [markdown]
# <FONT SIZE=4 COLOR="magenta"> 5.4 Agregar una variable </FONT>
#
# Para agregar una variable usamos la instrucción
#
# $$datos[``\text{nueva variable}"] = lista $$

# %%
diabetes["BMI/Age"]= diabetes["BMI"]/diabetes["Age"]

# %%
diabetes.head()

# %% [markdown]
# ## <FONT SIZE=4 COLOR="magenta"> 5.5 Agrupaciones: ***groupby()*** </FONT>
#
# - Se usa para agrupar una variable por sus categorías y luego aplicar una función a estos grupos con respecto a otra variable
#
# <center><img src="https://github.com/Fabian830348/cursos/blob/master/intro/groupby1.png?raw=true" alt="centered image" width="450" height="350"></center> <center><figcaption> <FONT SIZE=1 COLOR="black"> Fuente: Elaboración propia  </FONT> <figcaption></center>

# %%
diabetes.groupby("Outcome")

# %% [markdown]
# Observe que no se genera nada. Esto es porque internamente lo que hace pandas es agrupar por las clases o categorias de la variable.
#
# **¿Qué podemos hacer con esto?**

# %%
# calcula as estadísticas de la variable Glucosa en cada categoría de Outcome
diabetes.groupby("Outcome").Glucose.describe()

# %% [markdown]
# # <FONT SIZE=5 COLOR="green"> 6. Algunas funciones importantes </FONT>

# %% [markdown]
# 1. Media o promedio: **.mean()**
#
# - Es el "equilibrio" de los datos.
# - Se usa para variables cuantitativas.
# - Siempre está entre el mínimo y máximo de los datos.
# - Es sensible a datos atípicos. Por está razón se debe tener cuidado con su interpretación.

# %%
diabetes.Age.mean()

# %% [markdown]
# 2. Mediana: **.median()**
#
# - Es el valor que divide los datos en dos partes iguales (50%-50%)
# - Aplica para variables cuantitativas
# - Puede o no estar en el conjunto de datos. Depende si se tiene un número par o impar de elementos.
# - No se ve afectada por la existencia de datos atípicos. Por está razón en ocaciones se usa para imputación.

# %%
diabetes.Age.median()

# %% [markdown]
# 3. Moda: **.mode()**
#
# - Es el valor que más se repite. Es decir el que tiene mayor frecuencia
# - Aplica para variables cualitativas y cuantitativas
# - UN conjunto puede no tener o tener múltiples modas.

# %%
diabetes.Age.mode()

# %% [markdown]
# 4. Máximo y mínimo del conjunto: **.max** y **.min**

# %%
diabetes.Age.max()

# %%
diabetes.Age.min()

# %% [markdown]
# # <FONT SIZE=5 COLOR="green"> 7. Herramientas Adicionales de Visualización </FONT>
# Existen muchas herramientas para generar reportes que resumen la información de un conjunto de datos. Entre ellas, tenemos a **sweetviz**

# %%
# !pip install sweetviz

# %%
import sweetviz as sw

# %%
reporte=sw.analyze(diabetes, target_feat= "Outcome")

# %%
from IPython.display import HTML
reporte.show_html()
HTML("SWEETVIZ_REPORT.html")

# %% [markdown]
# # <FONT SIZE=4 COLOR="Purple"> 8. Ejercicio </FONT>
#
# 1. Importar los siguientes datos que representan algunas características de apartamentos en diferentes zonas de Medellín.
#
# https://raw.githubusercontent.com/Fabian830348/Bases_Datos/master/APARTAMENTOS.csv
#
# 2. ¿Cuál es el tamaño de los datos?
#
# 3. Haga una exploración de los datos.
#
# 4. ¿Cuál variable es conveniente eliminar?
#
# 5. Adicione al dataframe una variable de precio por metro cuadrado.
#
# 6. Haga un diagrama de barras y de tortas para la variable *ubicacion*.
#
# 7. Analice la variable *precio*. Qué tipo de gráfico se puede usar en este caso.
#
# 8. Qué representa el siguiente código
#
# ```python
# px.box(aptos,                                                 # nombre de los datos
#              y = "precio",                                    # variable cuantitativa
#              x = "ubicacion",                                 # variable cualitativa o categórica
#              title = "Boxplot variable precio vs ubicación",  # título del gráfico
#              color = "ubicacion"                              # color por la variable categórica
#              )
# ```
#
# 9. Calcule las estadísticas descriptivas de la variable *precio* en cada una de las *ubicaciones*. Haga los mismo con *mt2* e interprete.
#
# 10. Realice una tabla de contingencia de las variables *alcobas* y *banos*.
#
# 11. Realice un diagrama de dispersión de las variables *precio* y *mt2* e identifique con colores la *ubicacion*.
